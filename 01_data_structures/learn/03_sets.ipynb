# %% [markdown]
# # Introduction to Sets in Python
#
# In this tutorial, we'll learn about sets in Python and how to perform common
# operations like adding, removing, and iterating over elements. Sets are perfect
# for high school students learning Python as they are easy to understand and work
# with.

# %% [markdown]
# ## What is a Set?
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/uckNJuUsq_0" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# A set is an unordered collection of unique items. This means that each item in a
# set can only appear once. Sets are useful when you need to store and manipulate
# a collection of distinct elements without caring about their order.
#
# In Python, sets are created using curly braces `{}` or the `set()` constructor.
# Let's create a simple set with some numbers:

# %%
my_set = {1, 2, 3, 4, 5}
print(my_set)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Creating a Set**
#
# Create a set called `tags` using these values (including deliberate duplicates):
# `"python"`, `"coding"`, `"python"`, `"beginner"`, `"coding"`, `"tutorial"`
#
# Print the set and its length — notice duplicates are removed automatically.
#
# </div>

# %%
tags = {___, ___, ___, ___, ___, ___}
print(tags)
print("Unique tags:", len(tags))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# tags = {"python", "coding", "python", "beginner", "coding", "tutorial"}
# print(tags)                        # order may vary; 4 unique values
# print("Unique tags:", len(tags))   # 4
# ```
# </details>

# %% [markdown]
# ## Adding Elements to a Set
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/gpuOHt2QMGs" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# To add a new element to a set, we use the add() method:

# %%
my_set = {1, 2, 3, 4, 5}
my_set.add(6)
print(my_set)

# %% [markdown]
# If we try to add an element that already exists in the set, it won't change the set:

# %%
my_set.add(3)
print(my_set)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Adding to a Set**
#
# Start with `enrolled = {"Alice", "Bob", "Charlie"}`.
# 1. Add `"Diana"` and print the set.
# 2. Try adding `"Bob"` again and print — the set size should stay the same.
#
# </div>

# %%
enrolled = {"Alice", "Bob", "Charlie"}

# 1. Add "Diana"
enrolled.___(___)
print(enrolled)

# 2. Add "Bob" again
enrolled.___(___)
print(enrolled)           # same 4 elements
print("Size:", len(enrolled))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# enrolled = {"Alice", "Bob", "Charlie"}
#
# enrolled.add("Diana")
# print(enrolled)    # {"Alice", "Bob", "Charlie", "Diana"} — order may vary
#
# enrolled.add("Bob")
# print(enrolled)    # unchanged — no duplicates allowed
# print("Size:", len(enrolled))   # 4
# ```
# </details>

# %% [markdown]
# ## Removing Elements from a Set
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/g8R_KgG72i8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# To remove an element from a set, we can use the remove() method:

# %%
my_set = {1, 2, 3, 4, 5}
my_set.remove(3)
print(my_set)

# %% [markdown]
# If we try to remove an element that doesn't exist in the set, `remove()` will raise a `KeyError`. To avoid this, we can use the `discard()` method, which does not raise an error if the element is not found:

# %%
my_set.discard(3)
print(my_set)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Removing from a Set**
#
# Start with `inventory = {10, 20, 30, 40, 50}`.
# 1. Use `remove()` to remove `30` and print.
# 2. Use `discard()` to attempt removing `99` (not in set) — no error should occur. Print.
#
# </div>

# %%
inventory = {10, 20, 30, 40, 50}

# 1. Remove 30
inventory.___(___)
print(inventory)

# 2. Discard 99 (not in set)
inventory.___(___)
print(inventory)   # unchanged

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# inventory = {10, 20, 30, 40, 50}
#
# inventory.remove(30)
# print(inventory)     # {10, 20, 40, 50}
#
# inventory.discard(99)
# print(inventory)     # {10, 20, 40, 50} — no error, no change
# ```
# </details>

# %% [markdown]
# ## Iterating Over Elements in a Set
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/uB5TOB7jfSE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# As sets are unordered, we cannot access individual elements using an index.
# However, we can iterate over the elements using a for loop:

# %%
my_set = {1, 2, 3, 4, 5}

for number in my_set:
    print(number)

# %% [markdown]
# Remember that the order of the elements may be different when you run the code, as sets are unordered.

# %%
fruits = {"apple", "banana", "cherry"}

for fruit in fruits:
    print(fruit)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Iterating Over a Set**
#
# `fruits = {"apple", "banana", "cherry", "date"}`
#
# 1. Iterate and print every fruit (remember: order is not guaranteed).
# 2. Write a second loop that prints **only** fruits whose name is longer than 5 characters.
#
# </div>

# %%
fruits = {"apple", "banana", "cherry", "date"}

# 1. Print every fruit
for ___ in fruits:
    print(___)

# 2. Only fruits with names longer than 5 characters
for fruit in fruits:
    if len(___) > 5:
        print(___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# fruits = {"apple", "banana", "cherry", "date"}
#
# for fruit in fruits:
#     print(fruit)   # order may vary
#
# for fruit in fruits:
#     if len(fruit) > 5:
#         print(fruit)   # banana, cherry (order may vary)
# ```
# </details>

# %% [markdown]
# ## Comparing Sets: `issubset()` and `issuperset()`
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/56GuHAVVhHc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# In Python, you can check whether a set is a subset or a superset of another set using the `issubset()` and `issuperset()` methods respectively.
#
# A set A is considered a subset of set B if all elements of A are in B. Likewise, B is a superset of A if it contains all elements of A. Here's how you can do this:

# %%
A = {1, 2, 3}
B = {1, 2, 3, 4, 5}

print(A.issubset(B))  # Output: True
print(B.issuperset(A))  # Output: True

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — issubset() and issuperset()**
#
# ```python
# required = {"Python", "Git", "Linux"}
# skills_a = {"Python", "Git", "Linux", "Docker", "Kubernetes"}
# skills_b = {"Python", "Java"}
# ```
# 1. Check if `required` is a subset of `skills_a`
# 2. Check if `skills_a` is a superset of `required`
# 3. Check if `required` is a subset of `skills_b`
#
# </div>

# %%
required = {"Python", "Git", "Linux"}
skills_a = {"Python", "Git", "Linux", "Docker", "Kubernetes"}
skills_b = {"Python", "Java"}

# 1. Is required a subset of skills_a?
print(required.___(skills_a))

# 2. Is skills_a a superset of required?
print(skills_a.___(required))

# 3. Is required a subset of skills_b?
print(required.___(skills_b))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# required = {"Python", "Git", "Linux"}
# skills_a = {"Python", "Git", "Linux", "Docker", "Kubernetes"}
# skills_b = {"Python", "Java"}
#
# print(required.issubset(skills_a))    # True
# print(skills_a.issuperset(required))  # True
# print(required.issubset(skills_b))    # False — missing Git and Linux
# ```
# </details>

# %% [markdown]
# ## Difference between Sets: `difference()`
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/q1PjQ2bD3EE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# The `difference()` method allows you to find elements that are in one set but not in another. The syntax is `A.difference(B)`, which gives you elements in A but not in B. Here's how to use it:

# %%
print(B.difference(A))  # Output: {4, 5}

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — difference()**
#
# ```python
# all_students = {"Alice", "Bob", "Charlie", "Diana", "Eve"}
# passed       = {"Alice", "Charlie", "Eve"}
# ```
# Use `difference()` to find the students who did **not** pass.
#
# </div>

# %%
all_students = {"Alice", "Bob", "Charlie", "Diana", "Eve"}
passed       = {"Alice", "Charlie", "Eve"}

failed = all_students.___(___)
print(failed)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# all_students = {"Alice", "Bob", "Charlie", "Diana", "Eve"}
# passed       = {"Alice", "Charlie", "Eve"}
#
# failed = all_students.difference(passed)
# print(failed)   # {"Bob", "Diana"}
# ```
# </details>

# %% [markdown]
# ## Common Elements in Sets: `intersection()`
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/HU0EglDZnQ4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# The `intersection()` method returns a set containing the common elements of two or more sets. Here's how you can find the common elements between sets A and B:

# %%
C = {3, 4, 5, 6}
print(B.intersection(C))  # Output: {3, 4, 5}

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — intersection()**
#
# ```python
# python_class = {"Alice", "Bob", "Charlie", "Diana"}
# java_class   = {"Bob", "Diana", "Eve", "Frank"}
# ```
# Use `intersection()` to find students enrolled in **both** classes.
#
# </div>

# %%
python_class = {"Alice", "Bob", "Charlie", "Diana"}
java_class   = {"Bob", "Diana", "Eve", "Frank"}

both = python_class.___(___)
print(both)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# python_class = {"Alice", "Bob", "Charlie", "Diana"}
# java_class   = {"Bob", "Diana", "Eve", "Frank"}
#
# both = python_class.intersection(java_class)
# print(both)   # {"Bob", "Diana"}
# ```
# </details>

# %% [markdown]
# ## Combining Sets: `union()`
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/JP5Dt4gxrtY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# In Python, the `union()` method is used to combine two or more sets into a new set. This new set contains all the unique elements from all the sets.
#
# Here's an example:

# %%
A = {1, 2, 3}
B = {2, 3, 4}
C = {5, 6}

# Combine A and B
D = A.union(B)
print(D)  # Output: {1, 2, 3, 4}

# You can combine more than two sets
E = A.union(B, C)
print(E)  # Output: {1, 2, 3, 4, 5, 6}

# %% [markdown]
# Note: the `union()` method does not modify the original sets. It creates a new set that contains the unique elements from all sets.
#
# You can also use the `|` operator to achieve the same result. Here's an example:

# %%
F = A | B | C
print(F)  # Output: {1, 2, 3, 4, 5, 6}

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — union()**
#
# Three club rosters:
# ```python
# debate = {"Alice", "Bob"}
# chess  = {"Bob", "Charlie", "Diana"}
# art    = {"Diana", "Eve", "Alice"}
# ```
# 1. Use `union()` to get every unique member across all clubs.
# 2. Achieve the same result with the `|` operator.
#
# </div>

# %%
debate = {"Alice", "Bob"}
chess  = {"Bob", "Charlie", "Diana"}
art    = {"Diana", "Eve", "Alice"}

# 1. Using union()
everyone = debate.___(chess).___(art)
print(everyone)

# 2. Using |
everyone_2 = ___ | ___ | ___
print(everyone_2)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# debate = {"Alice", "Bob"}
# chess  = {"Bob", "Charlie", "Diana"}
# art    = {"Diana", "Eve", "Alice"}
#
# everyone   = debate.union(chess).union(art)
# print(everyone)     # {"Alice", "Bob", "Charlie", "Diana", "Eve"}
#
# everyone_2 = debate | chess | art
# print(everyone_2)   # same result
# ```
# </details>

# %% [markdown]
# The `union()` method and `|` operator are extremely useful when you want to gather all unique elements from multiple sets. Experiment with these tools and become more familiar with sets in Python! Happy coding!

# %% [markdown]
# ## Summary
#
# In this tutorial, we learned about sets in Python and how to perform common
# operations like adding, removing, and iterating over elements. Sets are a handy
# data structure for high school students, as they provide a simple and efficient
# way to work with unique collections.
#
# Keep practicing with sets, and you'll become more comfortable with them in no
# time!

# %% [markdown]
# ---
#
# ## Practice Problems
#
# The problems below combine all the skills from this notebook. Work through each step on your own before revealing the answer.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 1 — Removing Duplicates**
#
# A list of product codes contains duplicates.
# ```python
# codes = ["A001", "B002", "A001", "C003", "B002", "D004", "A001"]
# ```
# 1. Convert `codes` to a set called `unique_codes` and print it
# 2. Print how many duplicates were removed: `len(codes) - len(unique_codes)`
# 3. Convert `unique_codes` back to a list called `clean_codes` and print it
# 4. Check if `"E005"` is in `unique_codes` — print `"Found"` or `"Not found"`
#
# </div>

# %%
codes = ["A001", "B002", "A001", "C003", "B002", "D004", "A001"]

# 1. Convert to a set
unique_codes = ___(codes)
print(unique_codes)

# 2. Duplicates removed
print("Duplicates removed:", len(___) - len(___))

# 3. Back to a list
clean_codes = ___(unique_codes)
print(clean_codes)

# 4. Is "E005" present?
if ___ in unique_codes:
    print("Found")
else:
    print("Not found")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# codes = ["A001", "B002", "A001", "C003", "B002", "D004", "A001"]
#
# unique_codes = set(codes)
# print(unique_codes)   # {"A001", "B002", "C003", "D004"} — order may vary
#
# print("Duplicates removed:", len(codes) - len(unique_codes))   # 3
#
# clean_codes = list(unique_codes)
# print(clean_codes)
#
# if "E005" in unique_codes:
#     print("Found")
# else:
#     print("Not found")   # prints this
# ```
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 2 — Course Enrollment Analysis**
#
# ```python
# cs101 = {"Alice", "Bob", "Carol", "Dave", "Eve"}
# cs201 = {"Bob", "Carol", "Frank", "Grace"}
# cs301 = {"Carol", "Dave", "Grace", "Heidi"}
# ```
# 1. Find students enrolled in **both** cs101 and cs201
# 2. Find students in cs101 but **not** in cs201
# 3. Find every unique student across all three courses
# 4. Check if cs301 is a subset of cs101 — print the result
# 5. Find students **exclusively** in cs101 (not in cs201 or cs301) and print each name
#
# </div>

# %%
cs101 = {"Alice", "Bob", "Carol", "Dave", "Eve"}
cs201 = {"Bob", "Carol", "Frank", "Grace"}
cs301 = {"Carol", "Dave", "Grace", "Heidi"}

# 1. In BOTH cs101 and cs201
print(cs101.___(cs201))

# 2. In cs101 but NOT cs201
print(cs101.___(cs201))

# 3. Every unique student
print(cs101 | ___ | ___)

# 4. Is cs301 a subset of cs101?
print(cs301.___(cs101))

# 5. Students only in cs101
exclusive = cs101 - ___ - ___
for ___ in exclusive:
    print(___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# cs101 = {"Alice", "Bob", "Carol", "Dave", "Eve"}
# cs201 = {"Bob", "Carol", "Frank", "Grace"}
# cs301 = {"Carol", "Dave", "Grace", "Heidi"}
#
# print(cs101.intersection(cs201))   # {"Bob", "Carol"}
# print(cs101.difference(cs201))     # {"Alice", "Dave", "Eve"}
# print(cs101 | cs201 | cs301)       # all unique students
# print(cs301.issubset(cs101))       # False
#
# exclusive = cs101 - cs201 - cs301
# for student in exclusive:
#     print(student)   # Alice, Eve (order may vary)
# ```
# </details>
