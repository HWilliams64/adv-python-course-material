# %% [markdown]
# # Python Tuples Tutorial
#
# Welcome to this tutorial on tuples in Python! We'll cover the basics of tuples.

# %% [markdown]
# ## Tuples
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/QnzGCAUpH2g" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# A tuple is similar to a list, but it's immutable, which means you cannot add or remove elements after it's created. Tuples are often used to represent a collection of related values where each value has a specific meaning.

# %% [markdown]
# ### Creating a Tuple
#
# To create a tuple, simply put a comma-separated sequence of elements inside parentheses `()`:

# %%
coordinates = (42.3601, -71.0589)
print(coordinates)

# %% [markdown]
# This code creates a tuple called `coordinates` with two elements and then prints it out.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Creating a Tuple**
#
# Create a tuple called `student` that holds three values:
# your **name** (string), your **age** (int), and a **student ID** (string, e.g. `"S001"`).
# Print the tuple.
#
# </div>

# %%
# Create a tuple: name, age, student_id
student = (___, ___, ___)
print(student)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# student = ("Alex", 20, "S001")
# print(student)   # ("Alex", 20, "S001")
# ```
# </details>

# %% [markdown]
# ### Accessing Elements in a Tuple
#
# To access an element in a tuple, use indexing just like you would with a list:

# %%
latitude = coordinates[0]
longitude = coordinates[1]
print(latitude, longitude)

# %% [markdown]
# This code accesses the elements at positions 0 and 1 in the `coordinates` tuple and then prints them out.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Accessing Tuple Elements**
#
# `rgb = (255, 128, 0)` represents an orange colour as (red, green, blue).
# Access each channel by index and print:
# `Red: 255`, `Green: 128`, `Blue: 0`
#
# </div>

# %%
rgb = (255, 128, 0)

red   = rgb[___]
green = rgb[___]
blue  = rgb[___]

print("Red:",   red)
print("Green:", green)
print("Blue:",  blue)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# rgb = (255, 128, 0)
# red   = rgb[0]
# green = rgb[1]
# blue  = rgb[2]
# print("Red:",   red)    # Red:   255
# print("Green:", green)  # Green: 128
# print("Blue:",  blue)   # Blue:  0
# ```
# </details>

# %% [markdown]
# ### Iterating Over a Tuple
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/cHXEzMQi0yk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# To iterate over the elements in a tuple, you can use a for loop:

# %%
for coordinate in coordinates:
    print(coordinate)

# %% [markdown]
# This code prints each element in the `coordinates` tuple, one at a time.
#
# And that's it! You've learned the basics of lists and tuples in Python, how to add and remove elements from lists, and how to iterate over both lists and tuples. Happy coding!

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Iterating Over a Tuple**
#
# `days = ("Mon", "Tue", "Wed", "Thu", "Fri")`
#
# 1. Write a `for` loop that prints each day on its own line.
# 2. Write a second loop that uses a counter variable to print:
#    `Day 1 : Mon`, `Day 2 : Tue`, etc.
#
# </div>

# %%
days = ("Mon", "Tue", "Wed", "Thu", "Fri")

# 1. Print each day
for ___ in days:
    print(___)

# 2. Print with a day number
num = 1
for day in days:
    print("Day", ___, ":", ___)
    num += ___

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# days = ("Mon", "Tue", "Wed", "Thu", "Fri")
#
# for day in days:
#     print(day)
#
# num = 1
# for day in days:
#     print("Day", num, ":", day)
#     num += 1
# # Day 1 : Mon  /  Day 2 : Tue  /  ...
# ```
# </details>

# %% [markdown]
# ---
#
# ## Practice Problems
#
# The problems below combine all the skills from this notebook. Work through each step on your own before revealing the answer.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 1 — City Coordinates**
#
# GPS coordinates for three cities are stored as tuples inside a list.
# Work through each step in order.
#
# ```python
# cities = [
#     ("Boston",   42.36, -71.06),
#     ("New York", 40.71, -74.01),
#     ("Chicago",  41.88, -87.63)
# ]
# ```
#
# 1. Print the name of the **first** city
# 2. Print the **latitude** of the second city (index 1 of the list, index 1 of the tuple)
# 3. Iterate and print each city as: `Boston: lat=42.36, lon=-71.06`
#
# </div>

# %%
cities = [
    ("Boston",   42.36, -71.06),
    ("New York", 40.71, -74.01),
    ("Chicago",  41.88, -87.63)
]

# 1. Name of the first city
print(cities[___][___])

# 2. Latitude of the second city
print(cities[___][___])

# 3. Print each city
for city in cities:
    print(city[___], ": lat=", city[___], ", lon=", city[___], sep="")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# cities = [
#     ("Boston",   42.36, -71.06),
#     ("New York", 40.71, -74.01),
#     ("Chicago",  41.88, -87.63)
# ]
#
# print(cities[0][0])   # Boston
# print(cities[1][1])   # 40.71
#
# for city in cities:
#     print(city[0], ": lat=", city[1], ", lon=", city[2], sep="")
# # Boston: lat=42.36, lon=-71.06
# # New York: lat=40.71, lon=-74.01
# # Chicago: lat=41.88, lon=-87.63
# ```
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 2 — Student Record**
#
# A student's record is stored as a tuple. Even though the tuple is immutable,
# the **list** nested inside it can still be modified (you learned `append()` in lists!).
#
# ```python
# record = ("Sam", 3.7, 2, ["Python", "Calculus", "Data Structures"])
# ```
#
# 1. Print the student's name (index 0)
# 2. Print the GPA (index 1)
# 3. Access the courses list (index 3) and print how many courses there are
# 4. Append `"Statistics"` to the courses list and print the updated courses
# 5. Iterate over courses and print each one
#
# </div>

# %%
record = ("Sam", 3.7, 2, ["Python", "Calculus", "Data Structures"])

# 1. Student name
print(record[___])

# 2. GPA
print(record[___])

# 3. Number of courses
courses = record[___]
print("Courses:", len(___))

# 4. Append "Statistics"
courses.___(___)
print(courses)

# 5. Iterate over courses
for ___ in courses:
    print(___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# record = ("Sam", 3.7, 2, ["Python", "Calculus", "Data Structures"])
#
# print(record[0])   # Sam
# print(record[1])   # 3.7
#
# courses = record[3]
# print("Courses:", len(courses))   # Courses: 3
#
# courses.append("Statistics")
# print(courses)   # ["Python", "Calculus", "Data Structures", "Statistics"]
#
# for course in courses:
#     print(course)
# ```
# </details>
