# %% [markdown]
# # Python Dictionary Tutorial
#
# In this tutorial, we will learn about dictionaries in Python. We will cover the following topics:
#
# 1. What is a dictionary?
# 2. Creating a dictionary
# 3. Adding elements to a dictionary
# 4. Removing elements from a dictionary
# 5. Iterating over a dictionary

# %% [markdown]
# ## What is a dictionary?
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/s4o4RJVpe6A" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# A dictionary is a data structure in Python that stores key-value pairs. The keys
# are unique, and each key has a corresponding value. Dictionaries are useful when
# you need to store and retrieve data in pairs, like a phone book where names are
# keys and phone numbers are values.

# %% [markdown]
# ## Creating a dictionary
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/usWyesQ-CZk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# ## Using `{}`
# To create a dictionary, you can use the curly braces `{}` and separate keys and
# values with a colon `:`. Here's an example:

# %%
my_dict = {"apple": 2, "banana": 2, "cherry": 3, "apple": 1}
print(my_dict)

# %% [markdown]
# In this example, we created a dictionary named `my_dict` with three key-value pairs. The keys are "apple", "banana", and "cherry", and their corresponding values are 1, 2, and 3.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Creating a Dictionary with `{}`**
#
# Create a dictionary called `movie` with three key-value pairs:
# - `"title"`: `"Inception"`
# - `"year"`: `2010`
# - `"rating"`: `8.8`
#
# Print the dictionary.
#
# </div>

# %%
movie = {
    "___": "___",
    "___": ___,
    "___": ___
}
print(movie)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# movie = {
#     "title":  "Inception",
#     "year":   2010,
#     "rating": 8.8
# }
# print(movie)
# # {"title": "Inception", "year": 2010, "rating": 8.8}
# ```
# </details>

# %% [markdown]
# ### Using the `dict()` Constructor
#
# You can also create a dictionary using the `dict()` constructor. When using `dict()`, you don't use quotes around keys and you use equals signs rather than colons to associate keys with values.

# %%
person = dict(name='Bob', age=30, city='Boston')
print(person)  # Output: {'name': 'Bob', 'age': 30, 'city': 'Boston'}

# %% [markdown]
# ### Creating a Dictionary with Lists and Tuples
#
# You can create a dictionary from lists or tuples that contain key-value pairs. Here's an example:

# %%
items = [('name', 'Alice'), ('age', 25), ('city', 'New York')]
person = dict(items)
print(person)  # Output: {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %% [markdown]
# In this case, `items` is a list of tuples, and each tuple contains a key-value pair. The `dict()` function converts this list into a dictionary.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Creating with `dict()` and a List of Tuples**
#
# 1. Use `dict()` with **keyword arguments** to create `person`: `name="Sam"`, `age=22`, `city="Boston"`. Print it.
# 2. Convert this list of tuples into a dictionary called `scores` using `dict()`. Print it.
# ```python
# pairs = [("Math", 92), ("English", 85), ("Science", 90)]
# ```
#
# </div>

# %%
# 1. dict() with keyword arguments
person = dict(___)
print(person)

# 2. dict() from a list of tuples
pairs = [("Math", 92), ("English", 85), ("Science", 90)]
scores = dict(___)
print(scores)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# person = dict(name="Sam", age=22, city="Boston")
# print(person)   # {"name": "Sam", "age": 22, "city": "Boston"}
#
# pairs = [("Math", 92), ("English", 85), ("Science", 90)]
# scores = dict(pairs)
# print(scores)   # {"Math": 92, "English": 85, "Science": 90}
# ```
# </details>

# %% [markdown]
# ## Adding/Replacing elements to a dictionary
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/PwPPn5IDRLM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# To add a new key-value pair to a dictionary, you can use the square bracket []
# notation with the new key and assign a value to it. For example:

# %%
my_dict["orange"] = 4
print(my_dict)

# If the key already exist the value will be replaced
my_dict["orange"] = 5
print(my_dict)

# %% [markdown]
# Now, the `my_dict` dictionary has a new key-value pair: `"orange": 4`

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Adding and Replacing Values**
#
# Start with `cart = {"apple": 2, "banana": 3}`.
# 1. Add `"cherry"` with quantity `5` and print.
# 2. Update `"apple"` quantity to `4` (replace existing value) and print.
#
# </div>

# %%
cart = {"apple": 2, "banana": 3}

# 1. Add "cherry" with quantity 5
cart[___] = ___
print(cart)

# 2. Update "apple" quantity to 4
cart[___] = ___
print(cart)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# cart = {"apple": 2, "banana": 3}
#
# cart["cherry"] = 5
# print(cart)   # {"apple": 2, "banana": 3, "cherry": 5}
#
# cart["apple"] = 4
# print(cart)   # {"apple": 4, "banana": 3, "cherry": 5}
# ```
# </details>

# %% [markdown]
# ### Using the `update()` method
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/tO55GS1u-t8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# The `update()` method in Python is used to add new key-value pairs and also update the value of existing keys in a dictionary. Here's a simple example:

# %%
student = {
    'name': 'John Doe',
    'age': 21,
}

print(student)  # Output: {'name': 'John Doe', 'age': 21}

student.update({'age': 22, 'grade': 'Junior'})

print(student)  # Output: {'name': 'John Doe', 'age': 22, 'grade': 'Junior'}

# %% [markdown]
# In this example, we first define a dictionary `student` with two key-value pairs. We then use `update()` to modify the value of the 'age' key and add a new key-value pair ('grade': 'Junior').
#
# When using `update()`, if the provided key does not exist in the dictionary, the key-value pair is added. If the key already exists, the method updates the value for that key.
#
# The `update()` method can take a dictionary, an iterable with pairs (like list of tuples), or keyword arguments. Here are examples of each:

# %% [markdown]
# **Using another dictionary**

# %%
student.update({'major': 'Computer Science'})

# %% [markdown]
# **Using an iterable with pairs**

# %%
student.update([('grade', 'Senior'), ('GPA', 3.6)])

# %% [markdown]
# **Using keyword arguments**

# %%
student.update(major="Physics", GPA=3.8)

# %% [markdown]
# In all these examples, the `update()` method either adds new keys or updates the values of existing keys in the `student` dictionary. This makes `update()` a powerful tool for managing Python dictionaries.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Using update()**
#
# Start with `profile = {"username": "coder99", "level": 1}`.
# 1. Use `update()` with a **dictionary** to set `level=5` and add `xp=500`. Print.
# 2. Use `update()` with **keyword arguments** to add `badge="Gold"`. Print.
#
# </div>

# %%
profile = {"username": "coder99", "level": 1}

# 1. Update level and add xp using a dict
profile.update({___})
print(profile)

# 2. Add badge using keyword argument
profile.update(___)
print(profile)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# profile = {"username": "coder99", "level": 1}
#
# profile.update({"level": 5, "xp": 500})
# print(profile)   # {"username": "coder99", "level": 5, "xp": 500}
#
# profile.update(badge="Gold")
# print(profile)   # {"username": "coder99", "level": 5, "xp": 500, "badge": "Gold"}
# ```
# </details>

# %% [markdown]
# ## Accessing values
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/K35he-15P00" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# Getting a value from a Python dictionary is straightforward and can be achieved in two main ways:

# %% [markdown]
# ### Using Square Bracket Notation
#
# This is the most common and direct way to access a value in a dictionary. You simply use the key in square brackets to access the value.
#
# For example:

# %%
person = {
    'name': 'Alice',
    'age': 25,
    'city': 'New York'
}

print(person['name'])  # Output: Alice
print(person['age'])  # Output: 25

# %% [markdown]
# If the key exists in the dictionary, the corresponding value will be returned. However, if the key does not exist, Python will raise a `KeyError`.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Accessing Values with `[]`**
#
# `student = {"name": "Jamie", "gpa": 3.5, "major": "Computer Science", "year": 3}`
#
# 1. Print the student's name
# 2. Print the student's major
# 3. Print the sentence: `Jamie is a Year 3 Computer Science student.`
#
# </div>

# %%
student = {"name": "Jamie", "gpa": 3.5, "major": "Computer Science", "year": 3}

# 1. Name
print(student[___])

# 2. Major
print(student[___])

# 3. Full sentence
print(student[___], "is a Year", student[___], student[___], "student.")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# student = {"name": "Jamie", "gpa": 3.5, "major": "Computer Science", "year": 3}
#
# print(student["name"])    # Jamie
# print(student["major"])   # Computer Science
#
# print(student["name"], "is a Year", student["year"], student["major"], "student.")
# # Jamie is a Year 3 Computer Science student.
# ```
# </details>

# %% [markdown]
# ### Using the `get()` Method:
#
# This method allows you to access a value in a safer way. If the key does not exist, Python will return `None` or a default value of your choosing, instead of raising a `KeyError`.

# %%
print(person.get('city'))  # Output: New York
print(person.get('country'))  # Output: None
print(person.get('country', 'USA'))  # Output: USA

# %% [markdown]
# In the last example, since 'country' does not exist in the dictionary, the `get()` method returns the default value provided, 'USA'.
#
# Remember that keys in dictionaries are case-sensitive, so 'country' and 'Country' would be considered different keys. Also, keys in dictionaries must be immutable types, such as integers, floats, strings, or tuples, while values can be of any type.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Accessing Values with `get()`**
#
# `config = {"host": "localhost", "port": 8080}`
#
# 1. Use `get()` to retrieve `"host"`
# 2. Use `get()` to retrieve `"timeout"` — it doesn't exist; use a default of `30`
# 3. Use `get()` to retrieve `"port"`
#
# </div>

# %%
config = {"host": "localhost", "port": 8080}

# 1. Get "host"
print(config.get(___))

# 2. Get "timeout" with default 30
print(config.get(___, ___))

# 3. Get "port"
print(config.get(___))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# config = {"host": "localhost", "port": 8080}
#
# print(config.get("host"))           # localhost
# print(config.get("timeout", 30))    # 30 — key missing, returns default
# print(config.get("port"))           # 8080
# ```
# </details>

# %% [markdown]
# ## Checking if a Key is in a Dictionary
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/T1R67h8N-xw" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# Python provides several methods to check if a specific key is present in a dictionary. Here we'll discuss two common methods: using the `in` keyword and the `get()` method.

# %% [markdown]
# Using the `in` Keyword
# The `in` keyword is a straightforward way to check if a key exists in a dictionary. If the key is in the dictionary, `in` returns `True`; otherwise, it returns `False`. Here's an example:

# %%
person = {'name': 'Alice', 'age': 25, 'city': 'New York'}

# Check if 'name' is a key in the dictionary
if 'name' in person:
    print("'name' is a key in the dictionary")
else:
    print("'name' is not a key in the dictionary")

# %% [markdown]
# In this code, 'name' is indeed a key in the dictionary `person`, so the output will be: `'name' is a key in the dictionary`.

# %% [markdown]
# ### Using the `get()` Method
#
# The `get()` method is another way to check if a key exists in a dictionary. This method returns the value of the key if it exists in the dictionary. If the key doesn't exist, it returns `None` or a default value that you can specify.
#
# Here's an example:

# %%
person = {'name': 'Alice', 'age': 25, 'city': 'New York'}

# Use get() to check if 'name' is a key in the dictionary
if person.get('name') is not None:
    print("'name' is a key in the dictionary")
else:
    print("'name' is not a key in the dictionary")

# %% [markdown]
# In this case, because 'name' is a key in the dictionary `person`, the `get()` method returns its value ('Alice'), and the output will be: `'name' is a key in the dictionary'.
#
# The `get()` method can also return a default value if the key doesn't exist. Here's how you can do it:

# %% [markdown]
# In this example, since 'country' is not a key in the dictionary `person`, the `get()` method returns the default value (`False`), and the output will be: `'country' is not a key in the dictionary'.
#
# Both methods provide easy and efficient ways to check if a key exists in a Python dictionary. The `in` keyword is a good choice for simply checking key existence, while the `get()` method is handy when you want to retrieve the value of the key or a default value.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Checking if a Key Exists**
#
# `permissions = {"read": True, "write": False, "admin": False}`
#
# 1. Use `in` to check if `"delete"` is a key — print `"Permission exists"` or `"Permission missing"`
# 2. Use `in` to check if `"write"` is a key — print `"write permission found"`
# 3. Use `get()` to look up `"execute"` — print the result (should be `None`)
#
# </div>

# %%
permissions = {"read": True, "write": False, "admin": False}

# 1. Is "delete" a key?
if ___ in permissions:
    print("Permission exists")
else:
    print("Permission missing")

# 2. Is "write" a key?
if ___ in permissions:
    print("write permission found")

# 3. get() for "execute"
print(permissions.get(___))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# permissions = {"read": True, "write": False, "admin": False}
#
# if "delete" in permissions:
#     print("Permission exists")
# else:
#     print("Permission missing")    # prints this
#
# if "write" in permissions:
#     print("write permission found")   # prints this
#
# print(permissions.get("execute"))   # None
# ```
# </details>

# %% [markdown]
# ## Removing elements from a dictionary
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/Fq4K8-axKoE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# To remove a key-value pair from a dictionary, you can use the `del` keyword with the key that you want to remove. Here's an example:

# %%
del my_dict["banana"]
print(my_dict)

# %% [markdown]
# After executing this code, the key "banana" and its corresponding value 2 will be removed from my_dict.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Removing with `del`**
#
# `menu = {"burger": 8.99, "fries": 2.99, "soda": 1.99, "dessert": 4.99}`
#
# 1. Remove `"dessert"` using `del` and print.
# 2. Remove `"soda"` using `del` and print.
#
# </div>

# %%
menu = {"burger": 8.99, "fries": 2.99, "soda": 1.99, "dessert": 4.99}

# 1. Remove "dessert"
del menu[___]
print(menu)

# 2. Remove "soda"
del menu[___]
print(menu)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# menu = {"burger": 8.99, "fries": 2.99, "soda": 1.99, "dessert": 4.99}
#
# del menu["dessert"]
# print(menu)   # {"burger": 8.99, "fries": 2.99, "soda": 1.99}
#
# del menu["soda"]
# print(menu)   # {"burger": 8.99, "fries": 2.99}
# ```
# </details>

# %% [markdown]
# ## Iterating over a dictionary
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/BBzmncHZxXs" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# You can use a for loop to iterate over the keys or the key-value pairs of a dictionary. To iterate over the keys, you can use the .keys() method:

# %%
for key in my_dict:
    print(key)

# %% [markdown]
# To iterate over the key-value pairs, you can use the .items() method:

# %%
print(my_dict.items())
for key, value in my_dict.items():
    print(key, value)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Iterating over a Dictionary**
#
# `inventory = {"laptop": 5, "mouse": 12, "keyboard": 8, "monitor": 3}`
#
# 1. Iterate over **keys only** and print each.
# 2. Iterate using `.items()` and print each as: `laptop : 5 in stock`
#
# </div>

# %%
inventory = {"laptop": 5, "mouse": 12, "keyboard": 8, "monitor": 3}

# 1. Keys only
for ___ in inventory:
    print(___)

# 2. Key-value pairs
for ___, ___ in inventory.items():
    print(___, ":", ___, "in stock")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# inventory = {"laptop": 5, "mouse": 12, "keyboard": 8, "monitor": 3}
#
# for key in inventory:
#     print(key)
#
# for key, value in inventory.items():
#     print(key, ":", value, "in stock")
# # laptop : 5 in stock
# # mouse : 12 in stock
# # keyboard : 8 in stock
# # monitor : 3 in stock
# ```
# </details>

# %% [markdown]
# That's it! Now you know how to create, add, remove, and iterate over elements in a Python dictionary. Happy coding!

# %% [markdown]
# ---
#
# ## Practice Problems
#
# The problems below combine all the skills from this notebook. Work through each step on your own before revealing the answer.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 1 — Student Grade Book**
#
# Work through this grade book step by step — each step builds on the last.
# ```python
# grades = {"Alice": 88, "Bob": 72, "Charlie": 95, "Diana": 61, "Eve": 84}
# ```
# 1. Print Alice's grade using `[]`
# 2. Safely get `"Frank"`'s grade with `get()` — use `"Not enrolled"` as the default
# 3. Add Frank with grade `79`
# 4. Update Diana's grade to `75` (extra credit)
# 5. Remove Bob using `del`
# 6. Check if `"Charlie"` is still in grades — print a message
# 7. Iterate with `.items()` and print each as: `Alice : 88`
#
# </div>

# %%
grades = {"Alice": 88, "Bob": 72, "Charlie": 95, "Diana": 61, "Eve": 84}

# 1. Alice grade
print(grades[___])

# 2. Frank grade (not yet enrolled)
print(grades.get(___, ___))

# 3. Add Frank
grades[___] = ___

# 4. Update Diana
grades[___] = ___

# 5. Remove Bob
del grades[___]
print(grades)

# 6. Is Charlie still enrolled?
if ___ in grades:
    print("Charlie is enrolled")
else:
    print("Charlie not found")

# 7. Print all grades
for ___, ___ in grades.items():
    print(___, ":", ___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# grades = {"Alice": 88, "Bob": 72, "Charlie": 95, "Diana": 61, "Eve": 84}
#
# print(grades["Alice"])                       # 88
# print(grades.get("Frank", "Not enrolled"))   # Not enrolled
#
# grades["Frank"] = 79
# grades["Diana"] = 75
# del grades["Bob"]
# print(grades)
#
# if "Charlie" in grades:
#     print("Charlie is enrolled")   # prints this
#
# for name, grade in grades.items():
#     print(name, ":", grade)
# ```
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 2 — Nested Inventory**
#
# Each item in the inventory maps to a dict with `count` and `price`.
# ```python
# inventory = {
#     "apples":   {"count": 50,  "price": 0.99},
#     "bananas":  {"count": 30,  "price": 0.59},
#     "cherries": {"count": 200, "price": 3.99}
# }
# ```
# 1. Print the price of bananas *(nested access)*
# 2. Add `"dates"` with `count=80` and `price=2.49`
# 3. Update apple count to `45` *(5 were sold)*
# 4. Iterate and print items where `count < 100`: `apples : 45 in stock`
# 5. Use `get()` to check for `"elderberries"` — print the result
#
# </div>

# %%
inventory = {
    "apples":   {"count": 50,  "price": 0.99},
    "bananas":  {"count": 30,  "price": 0.59},
    "cherries": {"count": 200, "price": 3.99}
}

# 1. Price of bananas
print(inventory[___][___])

# 2. Add "dates"
inventory[___] = {"count": ___, "price": ___}

# 3. Update apple count to 45
inventory[___][___] = ___

# 4. Items with count < 100
for ___, ___ in inventory.items():
    if ___["count"] < 100:
        print(___, ":", ___["count"], "in stock")

# 5. Check for "elderberries"
print(inventory.get(___))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# inventory = {
#     "apples":   {"count": 50,  "price": 0.99},
#     "bananas":  {"count": 30,  "price": 0.59},
#     "cherries": {"count": 200, "price": 3.99}
# }
#
# print(inventory["bananas"]["price"])   # 0.59
#
# inventory["dates"] = {"count": 80, "price": 2.49}
# inventory["apples"]["count"] = 45
#
# for item, details in inventory.items():
#     if details["count"] < 100:
#         print(item, ":", details["count"], "in stock")
# # apples : 45 in stock
# # bananas : 30 in stock
# # dates : 80 in stock
#
# print(inventory.get("elderberries"))   # None
# ```
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 3 — Word Frequency Counter**
#
# Use a dictionary to count how many times each word appears.
# ```python
# words = ["apple", "banana", "apple", "cherry", "banana", "apple", "date"]
# ```
# 1. Create an empty dict called `frequency`
# 2. Loop over `words`: if the word is already a key add `1` to its count; otherwise set it to `1`
# 3. Print the full `frequency` dictionary
# 4. Print only words that appear **more than once**, with their count
# 5. Check if `"cherry"` is in `frequency` and print its count
#
# </div>

# %%
words = ["apple", "banana", "apple", "cherry", "banana", "apple", "date"]

# 1. Empty frequency dict
frequency = {}

# 2. Count occurrences
for word in words:
    if ___ in frequency:
        frequency[___] += 1
    else:
        frequency[___] = 1

# 3. Print full dict
print(frequency)

# 4. Words appearing more than once
for ___, ___ in frequency.items():
    if ___ > 1:
        print(___, ":", ___)

# 5. Cherry count
if ___ in frequency:
    print("cherry appears", frequency[___], "time(s)")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# words = ["apple", "banana", "apple", "cherry", "banana", "apple", "date"]
#
# frequency = {}
# for word in words:
#     if word in frequency:
#         frequency[word] += 1
#     else:
#         frequency[word] = 1
#
# print(frequency)
# # {"apple": 3, "banana": 2, "cherry": 1, "date": 1}
#
# for word, count in frequency.items():
#     if count > 1:
#         print(word, ":", count)
# # apple : 3
# # banana : 2
#
# if "cherry" in frequency:
#     print("cherry appears", frequency["cherry"], "time(s)")
# # cherry appears 1 time(s)
# ```
# </details>
