# %% [markdown]
# # Python Lists Tutorial
#
# Welcome to this tutorial on lists in Python! We'll cover the basics of lists.
#
# ## Lists
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/MGFfSf2_vjQ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# A list in Python is a mutable, ordered sequence of elements. Elements in a list
# can be of any data type, such as numbers, strings, or even other lists.

# %% [markdown]
# ## Creating a List

# %% [markdown]
# ### Creating a List with []
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/1y0G-BTKO9c" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# The easiest way to create a list is to enclose your data in square brackets `[]`. You can create a list of integers, strings, or even mix different types of data. Let's dive in:

# %%
# A list of integers
numbers = [1, 2, 3, 4, 5]
print(numbers)

# A list of strings
fruits = ["apple", "banana", "cherry"]
print(fruits)

# A list with mixed data types
mixed_list = [1, "two", 3.0, "four"]
print(mixed_list)

# %% [markdown]
# When you run the above code, it will print out the content of each list.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Creating Lists with `[]`**
#
# 1. Create a list called `movies` containing **5 of your favorite movie titles** and print it.
# 2. Create a list called `my_info` that holds your **name** (string), **age** (int), and **GPA** (float), then print it.
#
# </div>

# %%
# 1. A list of 5 favorite movies
movies = ["___", "___", "___", "___", "___"]
print(movies)

# 2. A mixed list: your name (str), age (int), GPA (float)
my_info = ["___", 0, 0.0]
print(my_info)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# movies = ["The Matrix", "Inception", "Interstellar", "The Dark Knight", "Parasite"]
# print(movies)
# # ['The Matrix', 'Inception', 'Interstellar', 'The Dark Knight', 'Parasite']
#
# my_info = ["Alex", 20, 3.8]
# print(my_info)
# # ['Alex', 20, 3.8]
# ```
# </details>

# %% [markdown]
# ### Creating a List with list()
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/iXZJYw8HzqM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# Another way to create a list is by using the built-in `list()` function.

# %%
# An empty list
empty_list = list()
print(empty_list)  # prints []

# Convert a string into a list of characters
char_list = list("hello")
print(char_list)  # prints ['h', 'e', 'l', 'l', 'o']

# Convert a tuple into a list
tuple_to_list = list((1, 2, 3, 4, 5))
print(tuple_to_list)  # prints [1, 2, 3, 4, 5]

# %% [markdown]
# As you can see, using `list()` gives you a bit more flexibility, especially when you want to convert other data types into a list.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Creating Lists with `list()`**
#
# 1. Use `list()` to convert the string `"Python"` into a list of characters and print it.
# 2. The tutorial converted `(1, 2, 3, 4, 5)` with `list()`. Do the same with `(100, 200, 300)` and print the result.
#
# </div>

# %%
# 1. Convert "Python" into a list of characters
char_list = list(___)
print(char_list)

# 2. Convert this tuple into a list
my_tuple = (100, 200, 300)
number_list = list(___)
print(number_list)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# char_list = list("Python")
# print(char_list)      # ['P', 'y', 't', 'h', 'o', 'n']
#
# my_tuple = (100, 200, 300)
# number_list = list(my_tuple)
# print(number_list)    # [100, 200, 300]
# ```
# </details>

# %% [markdown]
# This code creates a list called fruits with three elements and then prints it out.

# %% [markdown]
# ## Accessing elements within a List

# %% [markdown]
# ### Accessing Individual Elements
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/wkKyxw8CSN4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
#
# To access an individual element from a list, you use its index, which is its position within the list. Indexing in Python starts at 0, meaning the first element is at index 0, the second at index 1, and so on. Here's how you would access the first element of the `fruits` list:

# %%
fruits = ["apple", "banana", "cherry", "dates", "elderberry"]

print(fruits[0])

# %% [markdown]
# This would output: `apple`.
#
# To access the third element, you would use:

# %%
fruits = ["apple", "banana", "cherry", "dates", "elderberry"]

print(fruits[2])

# %% [markdown]
# This would output: `cherry`.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Accessing List Elements**
#
# Given the list below, write code to print:
# 1. The **first** element
# 2. The element at **index 3**
# 3. The **last** element — figure out its index from the number of items
#
# </div>

# %%
colors = ["red", "green", "blue", "yellow", "purple"]

# 1. Print the first element
print(colors[___])

# 2. Print the element at index 3
print(colors[___])

# 3. Print the last element (what is its index?)
print(colors[___])

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# colors = ["red", "green", "blue", "yellow", "purple"]
# print(colors[0])   # red     — index 0 is always the first element
# print(colors[3])   # yellow
# print(colors[4])   # purple  — 5 elements means the last index is 4
# ```
# </details>

# %% [markdown]
# ### Creating a Sub-list (Slicing)
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/SMQTYSpP6-s" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# In Python, you can create a sub-list from a list using a technique called 'slicing'. Slicing allows you to create a new list from a segment of an existing one.
#
# Slicing uses the syntax: `list[start:stop]`. `start` is the index where the slice starts (inclusive), and `stop` is where the slice ends (exclusive).
#
# Here's how you would create a sub-list with the second and third elements of the `fruits` list:

# %%
fruits = ["apple", "banana", "cherry", "dates", "elderberry"]

sub_fruits = fruits[1:3]
print(sub_fruits)

# %% [markdown]
# This would output: `['banana', 'cherry']`.
#
# Note: If you omit the `start`, slicing starts from the beginning of the list. If you omit the `stop`, slicing goes to the end of the list. For instance, `fruits[:3]` would give you a sub-list of the first three elements (`['apple', 'banana', 'cherry']`), and `fruits[2:]` would give you a sub-list of all elements from the third to the end (`['cherry', 'dates', 'elderberry']`).
#
# I hope this helps you get started with lists in Python! Practice creating your own lists, accessing individual elements, and creating sub-lists. Happy coding!

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Slicing Lists**
#
# Given `numbers = [10, 20, 30, 40, 50, 60, 70]`, use slicing to produce:
# 1. The first three numbers → `[10, 20, 30]`
# 2. Everything from index 4 to the end → `[50, 60, 70]`
# 3. The middle three numbers → `[30, 40, 50]`
#
# </div>

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]

# 1. First three numbers
first_three = numbers[___]
print(first_three)

# 2. From index 4 to the end
last_three = numbers[___]
print(last_three)

# 3. Middle three: 30, 40, 50
middle_three = numbers[___]
print(middle_three)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# numbers = [10, 20, 30, 40, 50, 60, 70]
#
# first_three  = numbers[:3]   # [10, 20, 30]  — omitting start means "from index 0"
# last_three   = numbers[4:]   # [50, 60, 70]  — omitting stop  means "to the end"
# middle_three = numbers[2:5]  # [30, 40, 50]
#
# print(first_three)
# print(last_three)
# print(middle_three)
# ```
# </details>

# %% [markdown]
# ## Replacing values in a List
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/XMAIpWwGg4Q" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# In this tutorial, we'll explore how to replace a value in a Python list. Lists are a type of data structure in Python that can hold an ordered sequence of items. We will assume you have basic knowledge of Python lists for this tutorial.

# %% [markdown]
# ### Replacing a Single Value in a List
#
# To replace a single value in a list, you'll first need to know the index of the value to be replaced. Python list indexing starts at 0, so the first item in the list is at index 0, the second item is at index 1, and so on.
#
# Here's how to replace a value in a Python list:

# %%
# Let's create a list of fruits
fruits = ["apple", "banana", "cherry"]

# Now, let's replace "banana" with "blueberry"
fruits[1] = "blueberry"

print(fruits)  # Output: ['apple', 'blueberry', 'cherry']

# %% [markdown]
# In the example above, we replaced the second item (index 1) in the list `fruits` with "blueberry".

# %% [markdown]
# ### Replacing Multiple Values in a List
#
# You can also replace multiple values in a list by specifying a range of indices. This is done using slice assignment. Here's an example:

# %%
# Let's create a list of numbers
numbers = [1, 2, 3, 4, 5, 6]

# Now, let's replace the second and third items with 8 and 9
numbers[1:3] = [8, 9]

print(numbers)  # Output: [1, 8, 9, 4, 5, 6]

# %% [markdown]
# In this example, we replaced the second and third items (indices 1 and 2) with 8 and 9.
#
# And that's it! Now you know how to replace a single value and multiple values in a Python list. Practice these operations to get comfortable with them. Happy coding!

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Replacing List Values**
#
# `grades = ["A", "C", "B", "D", "A"]` was recorded with two errors:
# 1. The grade at **index 1** should be `"B"` — fix it with index assignment and print.
# 2. Replace the grades at **indices 3 and 4** with `"A+"` and `"A+"` using **slice assignment**, then print.
#
# </div>

# %%
grades = ["A", "C", "B", "D", "A"]

# 1. Fix the grade at index 1 — it should be "B"
grades[___] = ___
print(grades)

# 2. Replace grades at indices 3 and 4 with "A+" and "A+"
grades[___] = ___
print(grades)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# grades = ["A", "C", "B", "D", "A"]
#
# grades[1] = "B"
# print(grades)         # ['A', 'B', 'B', 'D', 'A']
#
# grades[3:5] = ["A+", "A+"]
# print(grades)         # ['A', 'B', 'B', 'A+', 'A+']
# ```
# </details>

# %% [markdown]
# ## Adding Elements to a List
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/vE9rZ2_hW8g" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# To add an element to the end of a list, use the append() method:

# %%
fruits = ["apple", "banana", "cherry"]

fruits.append("orange")
print(fruits)

# %% [markdown]
# This code adds the string "orange" to the end of the fruits list and then prints it out.

# %% [markdown]
# To insert an element at a specific position in the list, use the `insert()` method:

# %%
fruits = ["apple", "banana", "cherry"]

fruits.insert(1, "grape")
print(fruits)

# %% [markdown]
# This code inserts the string "grape" at position 1 (Python uses zero-based indexing, so position 1 is the second position in the list) and then prints it out.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Adding Elements to a List**
#
# Start with `shopping = ["milk", "eggs"]`.
# 1. Use `append()` to add `"bread"` to the end and print the list.
# 2. Use `insert()` to add `"butter"` at index 1 (the second position) and print the list.
#
# </div>

# %%
shopping = ["milk", "eggs"]

# 1. Append "bread" to the end
shopping.___(___)
print(shopping)

# 2. Insert "butter" at index 1
shopping.___(1, ___)
print(shopping)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# shopping = ["milk", "eggs"]
#
# shopping.append("bread")
# print(shopping)          # ['milk', 'eggs', 'bread']
#
# shopping.insert(1, "butter")
# print(shopping)          # ['milk', 'butter', 'eggs', 'bread']
# ```
# </details>

# %% [markdown]
# ## Removing Elements from a List
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/KCL5qPDfnbc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# To remove an element from a list by its value, use the remove() method:

# %%
fruits = ["apple", "banana", "cherry"]

fruits.remove("banana")
print(fruits)

# %% [markdown]
# This code removes the string "banana" from the fruits list and then prints it out.

# %% [markdown]
# To remove an element from a list by its index, use the pop() method:

# %%
fruits = ["apple", "banana", "cherry"]

fruits.pop(1)
print(fruits)

# %% [markdown]
# This code removes the element at position 1 in the `fruits` list and then prints it out.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Removing Elements from a List**
#
# Start with `animals = ["cat", "dog", "fish", "bird", "hamster"]`.
# 1. Use `remove()` to remove `"fish"` **by value** and print the list.
# 2. Use `pop()` to remove the element at **index 1** from the updated list and print.
#
# </div>

# %%
animals = ["cat", "dog", "fish", "bird", "hamster"]

# 1. Remove "fish" by value
animals.___(___)
print(animals)

# 2. Remove the element at index 1
animals.pop(___)
print(animals)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# animals = ["cat", "dog", "fish", "bird", "hamster"]
#
# animals.remove("fish")
# print(animals)   # ['cat', 'dog', 'bird', 'hamster']
#
# animals.pop(1)   # 'dog' is now at index 1 after fish was removed
# print(animals)   # ['cat', 'bird', 'hamster']
# ```
# </details>

# %% [markdown]
# ## Iterating Over a List
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/konWtMDZtcY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# To iterate over the elements in a list, you can use a `for` loop:

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(fruit)

# %% [markdown]
# This code prints each element in the fruits list, one at a time.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Iterating Over a List**
#
# Given `temperatures = [72, 68, 85, 90, 77]`:
# 1. Write a `for` loop that prints each temperature on its own line.
# 2. Extend your loop to also show **which day** it is: `Day 1 : 72`, `Day 2 : 68`, etc.
#    *(Hint: create a counter variable before the loop and increment it by 1 each iteration.)*
#
# </div>

# %%
temperatures = [72, 68, 85, 90, 77]

# 1. Print each temperature
for temp in temperatures:
    print(___)

# 2. Print each temperature with its day number
day = 1
for temp in temperatures:
    print("Day", ___, ":", ___)
    day += ___

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# temperatures = [72, 68, 85, 90, 77]
#
# # Part 1
# for temp in temperatures:
#     print(temp)
#
# # Part 2
# day = 1
# for temp in temperatures:
#     print("Day", day, ":", temp)
#     day += 1
#
# # Output:
# # Day 1 : 72
# # Day 2 : 68
# # Day 3 : 85
# # Day 4 : 90
# # Day 5 : 77
# ```
# </details>

# %% [markdown]
# ## Check if a list contains a value with the `in` keyword
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/WA6R7Zv2J84" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# The `in` keyword in Python is used to check if a value is present in a sequence like a list, tuple, string, or dictionary. If the value is present, `in` returns `True`. Otherwise, it returns `False`.
#
# Here's an example of using `in` with a list:

# %%
fruits = ['apple', 'banana', 'cherry', 'orange']

if 'banana' in fruits:
    print("'banana' is in the list")
else:
    print("'banana' is not in the list")

# %% [markdown]
# In this example, 'banana' is indeed in the list `fruits`, so the output of this code will be: `'banana' is in the list`.
#
# You can also use `in` in a similar way to check if a value is not in a list by combining it with `not`:

# %%
if 'mango' not in fruits:
    print("'mango' is not in the list")
else:
    print("'mango' is in the list")

# %% [markdown]
# In this case, since 'mango' is not in the list `fruits`, the output will be: `'mango' is not in the list`.
#
# So, the `in` keyword provides a convenient way to check for the presence of a value in a list or other sequence in Python.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Try It Out — Checking Membership with `in`**
#
# Given `allowed_users = ["alice", "bob", "carol", "dave"]`:
# 1. Check if `"eve"` is in the list. Print `"eve has access"` or `"eve does not have access"`.
# 2. Use `not in` to check if `"carol"` is absent. Print `"carol is missing"` or `"carol is present"`.
#
# </div>

# %%
allowed_users = ["alice", "bob", "carol", "dave"]

# 1. Is "eve" in the list?
if ___ in allowed_users:
    print("eve has access")
else:
    print("eve does not have access")

# 2. Is "carol" NOT in the list?
if ___ not in allowed_users:
    print("carol is missing")
else:
    print("carol is present")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# allowed_users = ["alice", "bob", "carol", "dave"]
#
# if "eve" in allowed_users:
#     print("eve has access")
# else:
#     print("eve does not have access")  # prints — eve is not in the list
#
# if "carol" not in allowed_users:
#     print("carol is missing")
# else:
#     print("carol is present")          # prints — carol IS in the list
# ```
# </details>

# %% [markdown]
# ---
#
# ## Practice Problems
#
# The problems below combine all the list skills from this notebook. Work through each step on your own before revealing the answer.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 1 — Class Roster**
#
# You are maintaining a student roster. Complete each step in order — the list changes as you go.
#
# 1. Create a list called `roster` containing: `"Alice"`, `"Bob"`, `"Charlie"`, `"Diana"`, `"Eve"`
# 2. Print the student at index 2
# 3. `"Bob"` transferred out and `"Brian"` joined in his place — replace the name at index 1
# 4. A new student `"Frank"` enrolled — append him to the end
# 5. `"Eve"` dropped the course — remove her by value
# 6. Iterate over the roster and print each name
# 7. Check if `"Charlie"` is still in the roster; print `"Charlie is enrolled"` or `"Charlie not found"`
#
# </div>

# %%
# Step 1: Create the roster
roster = [___, ___, ___, ___, ___]

# Step 2: Print the student at index 2
print(roster[___])

# Step 3: Replace "Bob" (index 1) with "Brian"
roster[___] = ___
print(roster)

# Step 4: Append "Frank"
roster.___(___)
print(roster)

# Step 5: Remove "Eve" by value
roster.___(___)
print(roster)

# Step 6: Iterate and print each name
for name in roster:
    print(___)

# Step 7: Is "Charlie" still enrolled?
if ___ in roster:
    print("Charlie is enrolled")
else:
    print("Charlie not found")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# # Step 1
# roster = ["Alice", "Bob", "Charlie", "Diana", "Eve"]
#
# # Step 2
# print(roster[2])   # Charlie
#
# # Step 3
# roster[1] = "Brian"
# print(roster)   # ['Alice', 'Brian', 'Charlie', 'Diana', 'Eve']
#
# # Step 4
# roster.append("Frank")
# print(roster)   # ['Alice', 'Brian', 'Charlie', 'Diana', 'Eve', 'Frank']
#
# # Step 5
# roster.remove("Eve")
# print(roster)   # ['Alice', 'Brian', 'Charlie', 'Diana', 'Frank']
#
# # Step 6
# for name in roster:
#     print(name)
#
# # Step 7
# if "Charlie" in roster:
#     print("Charlie is enrolled")   # prints this
# else:
#     print("Charlie not found")
# ```
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 2 — Quiz Score Tracker**
#
# You are tracking quiz scores. Complete each step in order.
#
# 1. Create a list called `scores` with these values: `45, 72, 88, 61, 95, 30, 77`
# 2. Print the first score and the score at index 4
# 3. The score at index 5 was a data-entry error — it should be `83`. Fix it.
# 4. Slice out the scores at indices 2, 3, and 4 (stop before index 5) and store them in `mid_scores`
# 5. A final-round score of `91` came in — append it to `scores`
# 6. Iterate over `scores` with a counter and print each one as: `Round 1 : 45`, `Round 2 : 72`, etc.
#
# </div>

# %%
# Step 1: Create the scores list
scores = [45, 72, 88, 61, 95, 30, 77]

# Step 2: First score and score at index 4
print(scores[___])   # first score
print(scores[___])   # score at index 4

# Step 3: Fix the score at index 5 — it should be 83
scores[___] = ___
print(scores)

# Step 4: Slice indices 2, 3, 4 into mid_scores
mid_scores = scores[___]
print(mid_scores)

# Step 5: Append the final-round score of 91
scores.___(___)
print(scores)

# Step 6: Print each score labeled by round number
round_num = 1
for score in scores:
    print("Round", ___, ":", ___)
    round_num += ___

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# scores = [45, 72, 88, 61, 95, 30, 77]
#
# print(scores[0])   # 45
# print(scores[4])   # 95
#
# scores[5] = 83
# print(scores)   # [45, 72, 88, 61, 95, 83, 77]
#
# mid_scores = scores[2:5]
# print(mid_scores)   # [88, 61, 95]
#
# scores.append(91)
# print(scores)   # [45, 72, 88, 61, 95, 83, 77, 91]
#
# round_num = 1
# for score in scores:
#     print("Round", round_num, ":", score)
#     round_num += 1
#
# # Output:
# # Round 1 : 45
# # Round 2 : 72
# # Round 3 : 88  ... and so on
# ```
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
#
# **Practice Problem 3 — Bookshelf Manager**
#
# You are organising a bookshelf. This problem uses every list skill from the notebook.
#
# 1. Convert the tuple below into a list called `books` using `list()`
# 2. `"Fluent Python"` belongs at position 2 — insert it at index 2
# 3. `"You Don't Know JS"` was shelved by mistake — remove it by value
# 4. Slice out everything from index 2 to the end and store it in `back_shelf`
# 5. Check if `"Clean Code"` is in `books`; print `"Found on shelf"` or `"Not found"`
# 6. Iterate over `books` with a counter and print: `1 . Python Crash Course`, `2 . Clean Code`, etc.
#
# </div>

# %%
book_tuple = (
    "Python Crash Course", "Clean Code", "The Pragmatic Programmer",
    "You Don't Know JS", "Design Patterns"
)

# Step 1: Convert the tuple to a list
books = list(___)
print(books)

# Step 2: Insert "Fluent Python" at index 2
books.___(2, ___)
print(books)

# Step 3: Remove "You Don't Know JS" by value
books.remove(___)
print(books)

# Step 4: Slice from index 2 to the end into back_shelf
back_shelf = books[___]
print(back_shelf)

# Step 5: Is "Clean Code" in books?
if ___ in books:
    print("Found on shelf")
else:
    print("Not found")

# Step 6: Iterate with a counter
position = 1
for book in books:
    print(___, ".", ___)
    position += ___

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# book_tuple = (
#     "Python Crash Course", "Clean Code", "The Pragmatic Programmer",
#     "You Don't Know JS", "Design Patterns"
# )
#
# # Step 1
# books = list(book_tuple)
# print(books)
#
# # Step 2
# books.insert(2, "Fluent Python")
# print(books)
# # ['Python Crash Course', 'Clean Code', 'Fluent Python',
# #  'The Pragmatic Programmer', "You Don't Know JS", 'Design Patterns']
#
# # Step 3
# books.remove("You Don't Know JS")
# print(books)
# # ['Python Crash Course', 'Clean Code', 'Fluent Python',
# #  'The Pragmatic Programmer', 'Design Patterns']
#
# # Step 4
# back_shelf = books[2:]
# print(back_shelf)
# # ['Fluent Python', 'The Pragmatic Programmer', 'Design Patterns']
#
# # Step 5
# if "Clean Code" in books:
#     print("Found on shelf")   # prints this
# else:
#     print("Not found")
#
# # Step 6
# position = 1
# for book in books:
#     print(position, ".", book)
#     position += 1
#
# # Output:
# # 1 . Python Crash Course
# # 2 . Clean Code
# # 3 . Fluent Python
# # 4 . The Pragmatic Programmer
# # 5 . Design Patterns
# ```
# </details>
