# %% [markdown]
# # Introduction to Pandas and Handling CSV Files
#
# Pandas is a powerful Python library used for data manipulation and analysis,
# o,ffering data structures and operations for manipulating numerical tables and
# time series.
#
# Before we get started make sure you run the code cell below to ensure panda's is
# installed in your Workspace.

# %%
# !pip install pandas

# %% [markdown]
# ## What is Pandas?
#
# Pandas provides two key data structures: `DataFrame` and `Series`, with the former being a 2-dimensional labeled data structure with columns of potentially different types, and the latter a 1-dimensional labeled array.

# %%
import pandas as pd

# Example of creating a simple DataFrame
data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
        'Age': [28, 34, 29, 32]}
df = pd.DataFrame(data)

print(df)

# %% [markdown]
# - **DataFrame creation**: Here, we create a DataFrame from a dictionary. This structure is useful for representing real-world data in a tabular format.
# - **Printing DataFrame**: By printing the DataFrame, we can see its tabular structure with rows and columns.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Create a DataFrame from a Dictionary</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a Pandas DataFrame with columns 'product' (str), 'price' (float),
# and 'in_stock' (bool) for 4 products of your choosing. Print the DataFrame.</pre>
# </div>

# %%
import pandas as pd

data = {
    'product':  [___, ___, ___, ___],
    'price':    [___, ___, ___, ___],
    'in_stock': [___, ___, ___, ___],
}

df = pd.DataFrame(___)
print(df)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import pandas as pd
#
# data = {
#     'product':  ['Widget', 'Gadget', 'Doohickey', 'Thingamajig'],
#     'price':    [9.99, 24.99, 4.49, 14.99],
#     'in_stock': [True, False, True, True],
# }
#
# df = pd.DataFrame(data)
# print(df)
# ```
#
# </details>

# %% [markdown]
# ## What is a CSV File?
#
# A CSV (Comma-Separated Values) file is a type of plain text file that uses
# specific structuring to arrange tabular data. Because it's a plain text file, it
# can contain only actual text data—in other words, printable ASCII or Unicode
# characters.
#
# Often the data you will work with in a machine learning project is stored in a CSV file.

# %% [markdown]
# ## How to Load a CSV File
#
# To load a CSV file into a Pandas DataFrame, we use the `pd.read_csv()` function, providing it with the path to the file.

# %%
# Load a CSV file
df = pd.read_csv('./fictional-characters.csv')

print(df)

# %% [markdown]
# - **Loading CSV**: The `pd.read_csv()` function reads a CSV file and converts it into a DataFrame.
# - **Displaying the loaded DataFrame**: By printing the DataFrame, we see the data that was in the CSV file in a structured format.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Load a CSV and Inspect Its Size</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Load the fictional-characters.csv file into a DataFrame named df.
# Print its shape (rows, columns) using df.shape and the column names using df.columns.</pre>
# </div>

# %%
import pandas as pd

df = pd.read_csv(___)

print('Shape:', ___)
print('Columns:', ___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('./fictional-characters.csv')
#
# print('Shape:', df.shape)
# print('Columns:', df.columns.tolist())
# ```
#
# </details>

# %% [markdown]
# ## How to Look at the CSV File with `head()` and `info()`
#
# - **Using `head()`**: This function returns the first N rows of the DataFrame, which is useful for quickly testing if your DataFrame has the right type of data.
# - **Using `info()`**: This method provides a concise summary of the DataFrame, including the number of non-null entries in each column.

# %%
# Display the first 5 rows of the DataFrame
print(df.head())

# Get a concise summary of the DataFrame
print(df.info())

# %% [markdown]
# - **Inspecting the DataFrame**: `head()` helps us quickly peek at the data, while `info()` gives us a summary, including data types and missing values.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Explore with head() and info()</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Using the df loaded above, display only the first 3 rows with head(3).
# Then call info() to see data types and which columns have missing values.</pre>
# </div>

# %%
# Show the first 3 rows
print(___)

# Print column types and non-null counts
df.___()

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# print(df.head(3))
# df.info()
# ```
#
# </details>

# %% [markdown]
# ## Explore Different Data Wrangling Exercises
#
# Data wrangling, also known as data munging, involves cleaning, structuring, and enriching raw data into a desired format for better decision making in less time.

# %% [markdown]
# ### Filtering Data:
#
# Select rows based on column values.

# %%
# Filter rows where the character's age is greater than 100
older_than_30 = df[df['age'] > 30]
print(older_than_30)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Filter DataFrame Rows</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Filter the fictional-characters DataFrame to:
#   1. Show only characters from planet 'Earth'
#   2. Show characters with ability >= 7
# Print both results.</pre>
# </div>

# %%
# Characters from Earth
earth_chars = df[___]
print('Earth characters:')
print(earth_chars)

# Characters with ability >= 7
powerful = df[___]
print('\nPowerful characters (ability >= 7):')
print(powerful)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# earth_chars = df[df['planet'] == 'Earth']
# print('Earth characters:')
# print(earth_chars)
#
# powerful = df[df['ability'] >= 7]
# print('\nPowerful characters (ability >= 7):')
# print(powerful)
# ```
#
# </details>

# %% [markdown]
# ### Handling Missing Data:
#
# You might have noticed Yoda's age is missing. Below we identify and fill missing
# age values with the mean of all the ages.

# %%
# Fill missing values in 'age' column with the mean age
df['age'].fillna(df['age'].mean(), inplace=True)
print(df)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Identify and Fill Missing Values</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Count missing values in each column using df.isnull().sum().
# Then fill any missing 'age' values with the column median (not mean).
# Print the missing-value counts and the updated 'age' column.</pre>
# </div>

# %%
# Count missing values per column
print(___)

# Fill missing 'age' values with the median
median_age = df['age'].___()
df['age'].fillna(___, inplace=True)
print('Median used:', median_age)
print(df['age'])

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# print(df.isnull().sum())
#
# median_age = df['age'].median()
# df['age'].fillna(median_age, inplace=True)
# print('Median used:', median_age)
# print(df['age'])
# ```
#
# </details>

# %% [markdown]
# ### Adding Columns:
#
# Compute new columns based on existing ones.

# %%
# Add a new column 'AgeNextYear'
df['AgeNextYear'] = df['age'] + 1
print(df)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Add a Computed Column</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Add two new columns to the fictional-characters DataFrame:
#   - 'PowerScore': ability * 10
#   - 'AgeGroup': 'Ancient' if age >= 100, otherwise 'Young'
# Print the firstName, age, ability, PowerScore, and AgeGroup columns.</pre>
# </div>

# %%
# PowerScore = ability * 10
df['PowerScore'] = ___

# AgeGroup based on age
df['AgeGroup'] = df['age'].apply(lambda x: ___)

print(df[['firstName', 'age', 'ability', 'PowerScore', 'AgeGroup']])

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# df['PowerScore'] = df['ability'] * 10
#
# df['AgeGroup'] = df['age'].apply(lambda x: 'Ancient' if x >= 100 else 'Young')
#
# print(df[['firstName', 'age', 'ability', 'PowerScore', 'AgeGroup']])
# ```
#
# </details>

# %% [markdown]
# ### 5. **Grouping and Aggregating**:
#
# Group data and calculate aggregate statistics. Below we are grouping all the
# characters by their home planet then calculating the average age of each
# characters from the same home planet. As you will see the average age of
# characters from earth is 134.6 years old.

# %%
# Group by 'Name' and calculate mean age
grouped = df.groupby('planet')['age'].mean()
print(grouped)

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Group and Aggregate</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Group the fictional-characters DataFrame by 'planet' and compute:
#   - mean_ability: the average ability per planet
#   - max_age: the oldest character on each planet
# Print the result sorted by mean_ability descending.</pre>
# </div>

# %%
grouped = df.groupby('planet').agg(
    mean_ability = ___,
    max_age      = ___,
)

print(grouped.sort_values(by='mean_ability', ascending=___))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# grouped = df.groupby('planet').agg(
#     mean_ability=('ability', 'mean'),
#     max_age=('age', 'max'),
# )
#
# print(grouped.sort_values(by='mean_ability', ascending=False))
# ```
#
# </details>

# %% [markdown]
# - **Practical Examples**: These examples demonstrate how to manipulate and analyze data using Pandas, including filtering, adding new data, handling missing values, and aggregating data.
#
# These steps offer a starting point for data analysis with Pandas, providing tools to load, view, and wrangle data from CSV files effectively.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 1: Student Report Card</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Build a student report card using pandas wrangling steps:
#
#   1. Create a DataFrame with columns 'name', 'exam1', 'exam2', 'exam3'
#      (use at least 5 students; leave one score as None for a missing grade)
#   2. Fill missing scores with the column mean
#   3. Add an 'average' column: mean of the three exams
#   4. Add a 'grade' column: 'A' (avg >= 90), 'B' (avg >= 80), 'C' (avg >= 70), 'F' (below 70)
#   5. Print the full report sorted by average descending</pre>
# </div>

# %%
import pandas as pd
import numpy as np

data = {
    'name':  ['Alice', 'Bob', 'Carol', 'Dave', 'Eve'],
    'exam1': [92, 78, None, 65, 88],
    'exam2': [85, 82, 90, 70, 94],
    'exam3': [91, 74, 88, None, 97],
}

df = pd.DataFrame(data)

# Step 2: Fill missing scores with the column mean
for col in ['exam1', 'exam2', 'exam3']:
    df[col].fillna(___, inplace=True)

# Step 3: Add average column
df['average'] = ___

# Step 4: Add grade column
def assign_grade(avg):
    if avg >= 90: return ___
    elif avg >= 80: return ___
    elif avg >= 70: return ___
    else: return ___

df['grade'] = df['average'].apply(assign_grade)

# Step 5: Print sorted by average descending
print(df.sort_values(by='average', ascending=False))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import pandas as pd
# import numpy as np
#
# data = {
#     'name':  ['Alice', 'Bob', 'Carol', 'Dave', 'Eve'],
#     'exam1': [92, 78, None, 65, 88],
#     'exam2': [85, 82, 90, 70, 94],
#     'exam3': [91, 74, 88, None, 97],
# }
#
# df = pd.DataFrame(data)
#
# for col in ['exam1', 'exam2', 'exam3']:
#     df[col].fillna(df[col].mean(), inplace=True)
#
# df['average'] = df[['exam1', 'exam2', 'exam3']].mean(axis=1)
#
# def assign_grade(avg):
#     if avg >= 90: return 'A'
#     elif avg >= 80: return 'B'
#     elif avg >= 70: return 'C'
#     else: return 'F'
#
# df['grade'] = df['average'].apply(assign_grade)
#
# print(df.sort_values(by='average', ascending=False))
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 2: Planet Power Analysis</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Using fictional-characters.csv, build a multi-step analysis:
#
#   1. Load the CSV and fill missing 'age' values with the median age
#   2. Add a 'fullName' column (firstName + ' ' + lastName)
#   3. Filter to characters with ability >= 5
#   4. Group by 'planet', computing mean ability and character count
#   5. Print results sorted by character count descending</pre>
# </div>

# %%
import pandas as pd

# Step 1: Load and fill missing ages
df = pd.read_csv('./fictional-characters.csv')
df['age'].fillna(___, inplace=True)

# Step 2: Add fullName
df['fullName'] = ___

# Step 3: Filter to ability >= 5
df_filtered = df[___]

# Step 4: Groupby planet
summary = df_filtered.groupby('planet').agg(
    mean_ability = ___,
    character_count = ___,
)

# Step 5: Sort by character count
print(summary.sort_values(by='character_count', ascending=False))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('./fictional-characters.csv')
# df['age'].fillna(df['age'].median(), inplace=True)
#
# df['fullName'] = df['firstName'].astype(str) + ' ' + df['lastName'].astype(str)
#
# df_filtered = df[df['ability'] >= 5]
#
# summary = df_filtered.groupby('planet').agg(
#     mean_ability=('ability', 'mean'),
#     character_count=('firstName', 'count'),
# )
#
# print(summary.sort_values(by='character_count', ascending=False))
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 3: Product Sales Analysis</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a sales DataFrame and analyze it with the full wrangling toolkit:
#
#   1. Create a DataFrame with columns 'product', 'category', 'units_sold', 'price_per_unit'
#      (at least 6 rows; include at least two categories)
#   2. Add a 'revenue' column: units_sold * price_per_unit
#   3. Add a 'tier' column: 'High' if revenue >= 500, otherwise 'Low'
#   4. Group by 'category' to find total revenue and mean units_sold per category
#   5. Print the product with the single highest revenue</pre>
# </div>

# %%
import pandas as pd

data = {
    'product':        ['Widget', 'Gadget', 'Doohickey', 'Thingamajig', 'Gizmo', 'Whatsit'],
    'category':       ['Tools', 'Electronics', 'Tools', 'Electronics', 'Tools', 'Electronics'],
    'units_sold':     [120, 45, 200, 30, 80, 60],
    'price_per_unit': [4.99, 29.99, 2.49, 49.99, 9.99, 19.99],
}

df = pd.DataFrame(data)

# Step 2: Revenue
df['revenue'] = ___

# Step 3: Tier
df['tier'] = df['revenue'].apply(lambda r: ___)

# Step 4: Group by category
cat_summary = df.groupby('category').agg(
    total_revenue = ___,
    mean_units    = ___,
)
print(cat_summary)

# Step 5: Top product
top = df.loc[df['revenue'].___()]
print('\nTop product:', top['product'], '| Revenue:', top['revenue'])

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import pandas as pd
#
# data = {
#     'product':        ['Widget', 'Gadget', 'Doohickey', 'Thingamajig', 'Gizmo', 'Whatsit'],
#     'category':       ['Tools', 'Electronics', 'Tools', 'Electronics', 'Tools', 'Electronics'],
#     'units_sold':     [120, 45, 200, 30, 80, 60],
#     'price_per_unit': [4.99, 29.99, 2.49, 49.99, 9.99, 19.99],
# }
#
# df = pd.DataFrame(data)
#
# df['revenue'] = df['units_sold'] * df['price_per_unit']
#
# df['tier'] = df['revenue'].apply(lambda r: 'High' if r >= 500 else 'Low')
#
# cat_summary = df.groupby('category').agg(
#     total_revenue=('revenue', 'sum'),
#     mean_units=('units_sold', 'mean'),
# )
# print(cat_summary)
#
# top = df.loc[df['revenue'].idxmax()]
# print('\nTop product:', top['product'], '| Revenue:', top['revenue'])
# ```
#
# </details>
