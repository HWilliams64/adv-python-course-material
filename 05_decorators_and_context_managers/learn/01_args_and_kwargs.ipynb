# %% [markdown]
# # Understanding *args and **kwargs in Python
#
# In Python, `*args` and `**kwargs` are special operators used in function definitions. `*args` is used to pass a variable number of non-keyword arguments to a function, while `**kwargs` allows you to pass a variable number of keyword arguments. These operators make your functions flexible, allowing them to handle a variety of input parameters without needing to define each one individually.

# %% [markdown]
# ## The Power of *args
#
# `*args` allows a function to accept any number of positional arguments. This means you can pass as many arguments as you wish to the function without explicitly defining each parameter in the function's definition.

# %%
def add_numbers(*args):
    return sum(args)

print(add_numbers(3, 5))
print(add_numbers(4, 5, 6, 7))

# %% [markdown]
# - The `*args` parameter in the `add_numbers` function collects all the positional arguments passed to the function into a tuple.
# - The `sum()` function is then used to add all the numbers in the tuple.
# - This approach makes `add_numbers` highly versatile, as it can handle any number of arguments.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Accept Any Number of Positional Arguments with *args</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Write a function multiply_all(*args) that returns the product of all its
# positional arguments. Return 1 if no arguments are passed.
# Test with multiply_all(2, 3, 4), multiply_all(5), and multiply_all().</pre>
# </div>

# %%
def multiply_all(*args):
    result = 1
    for num in ___:
        result = result * num
    return result

print(multiply_all(2, 3, 4))  # Expected: 24
print(multiply_all(5))         # Expected: 5
print(multiply_all())          # Expected: 1

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# def multiply_all(*args):
#     result = 1
#     for num in args:
#         result = result * num
#     return result
#
# print(multiply_all(2, 3, 4))  # 24
# print(multiply_all(5))         # 5
# print(multiply_all())          # 1
# ```
#
# </details>

# %% [markdown]
# ## Exploring **kwargs
#
# `**kwargs` works similarly to `*args`, but for keyword arguments. It allows you to handle named arguments dynamically, collecting them into a dictionary.

# %%
def introduce_yourself(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

introduce_yourself(name="Tanya", age=20, hobby="coding")

# %% [markdown]
# - The `**kwargs` parameter collects all the keyword arguments into a dictionary.
# - The function iterates over the dictionary, printing out each key-value pair.
# - This method is useful for functions that require a flexible number of named parameters.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Accept Any Number of Keyword Arguments with **kwargs</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Write a function build_address(**kwargs) that prints each key-value pair
# on its own line. Test it with two different sets of address details.</pre>
# </div>

# %%
def build_address(**kwargs):
    # Print each key: value pair on its own line
    for key, value in ___.items():
        print(key + ': ' + str(value))

build_address(street="123 Main St", city="Boston", state="MA")
print()
build_address(city="Cambridge", zip_code="02139")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# def build_address(**kwargs):
#     for key, value in kwargs.items():
#         print(key + ': ' + str(value))
#
# build_address(street="123 Main St", city="Boston", state="MA")
# print()
# build_address(city="Cambridge", zip_code="02139")
# ```
#
# </details>

# %% [markdown]
# ## Try it out
#
# Now, it's your turn to practice! Write a function called `create_profile` that accepts a name and any number of additional keyword arguments. The function should print out the name and then any of the additional information received (like age, profession, and hobbies).

# %%
def create_profile(name, **kwargs):
    # Your code here. Print the name and any other information provided.
    pass

# %% [markdown]
# Try calling your function with various combinations of information to see how it handles different amounts of keyword arguments.

# %% [markdown]
# ## Combining *args and **kwargs in Functions
#
# Python allows for even greater flexibility by combining `*args` and `**kwargs` in a single function definition. This enables the function to accept an arbitrary number of both positional and keyword arguments. The key to using them together is to ensure `*args` comes before `**kwargs` in the function definition.

# %% [markdown]
# ### Handling Both *args and **kwargs
#
# When you combine `*args` and `**kwargs`, `*args` captures unspecified positional arguments as a tuple, and `**kwargs` captures unspecified keyword arguments as a dictionary. This combination allows a function to accept virtually any form of arguments passed to it.

# %%
def register_participant(*args, **kwargs):
    print("Participant Details:")
    for arg in args:
        print(arg)
    print("\nAdditional Information:")
    for key in kwargs:
        print(f"{key}: {kwargs[key]}")

register_participant("Tony", "Stark", age=45, nickname="ironman")

# %% [markdown]
# - This example showcases a `register_participant` function that can take multiple types of data about a participant.
# - The positional arguments (`*args`) might represent essential participant information, like name and skill level.
# - The keyword arguments (`**kwargs`) can include any additional details provided upon registration.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Combine *args and **kwargs in One Function</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Write a function order_summary(*items, **details) that:
#   - Prints 'Items ordered:' followed by each item on its own line
#   - Prints 'Order details:' followed by each key-value pair
# Then call it with three food items and customer/table/paid as keyword args.</pre>
# </div>

# %%
def order_summary(*items, **details):
    print("Items ordered:")
    for item in ___:
        print("  -", item)
    print("Order details:")
    for key, value in ___.items():
        print("  " + key + ":", value)

order_summary("Pizza", "Soda", "Breadsticks",
              customer="Alice", table=5, paid=True)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# def order_summary(*items, **details):
#     print("Items ordered:")
#     for item in items:
#         print("  -", item)
#     print("Order details:")
#     for key, value in details.items():
#         print("  " + key + ":", value)
#
# order_summary("Pizza", "Soda", "Breadsticks",
#               customer="Alice", table=5, paid=True)
# ```
#
# </details>

# %% [markdown]
# ### Guidelines for Using *args and **kwargs Together
#
# - **Order Matters**: Always put `*args` before `**kwargs` in the function definition to avoid syntax errors.
# - **Clarity is Key**: Use these features to make your functions flexible, but avoid overcomplicating function signatures.
# - **Documentation**: Always document what kinds of positional and keyword arguments your function expects. This makes your code more readable and user-friendly.

# %% [markdown]
# ### Try it out
#
# Create a function `plan_event` that accepts a title and a date as positional arguments, and any number of additional keyword arguments representing other details about the event (like location, time, and the name of the guest speaker). Use `*args` for the title and date, and `**kwargs` for the additional details. Print out all the information in an organized format.

# %%
def plan_event(*args, **kwargs):
    # Your code here to print event details.
    pass

# %% [markdown]
# Experiment with calling `plan_event` using different combinations of arguments to see how it handles them. This exercise will give you a practical understanding of how to leverage the power of both `*args` and `**kwargs` in Python.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 1: Flexible Statistics Function</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Write a function stats(*values, **options) that:
#   - Computes the min, max, and mean of all positional values
#   - Accepts optional keyword arguments:
#       round_to (int, default 2) — decimal places to round the mean
#       label    (str, default '') — a header printed before the stats
#   - Prints the label (if provided), then min / max / mean
#
# Test with:
#   stats(85, 92, 78, 95, 88, label='Exam Scores', round_to=1)
#   stats(1500, 2300, 1800, 2100, label='Monthly Sales')</pre>
# </div>

# %%
def stats(*values, **options):
    round_to = options.get(___, 2)
    label    = options.get(___, '')

    if label:
        print("=== " + label + " ===")

    print("Min: ", ___)
    print("Max: ", ___)
    print("Mean:", round(sum(values) / len(values), round_to))

stats(85, 92, 78, 95, 88, label="Exam Scores", round_to=1)
print()
stats(1500, 2300, 1800, 2100, label="Monthly Sales")

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# def stats(*values, **options):
#     round_to = options.get('round_to', 2)
#     label    = options.get('label', '')
#
#     if label:
#         print("=== " + label + " ===")
#
#     print("Min: ", min(values))
#     print("Max: ", max(values))
#     print("Mean:", round(sum(values) / len(values), round_to))
#
# stats(85, 92, 78, 95, 88, label="Exam Scores", round_to=1)
# print()
# stats(1500, 2300, 1800, 2100, label="Monthly Sales")
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 2: Dynamic CSV Row Builder</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Write a function build_csv_row(*values, **formatting) that:
#   - Joins all positional values into a delimiter-separated string
#   - Accepts keyword arguments:
#       delimiter (str, default ',') — character used to join values
#       quote (bool, default False) — if True, wrap each value in double quotes
#   - Returns the formatted string
#
# Test with:
#   print(build_csv_row('Alice', 92, 'A'))
#   print(build_csv_row('Bob', 78, 'C', delimiter='|', quote=True))</pre>
# </div>

# %%
def build_csv_row(*values, **formatting):
    delimiter = formatting.get(___, ',')
    quote     = formatting.get(___, False)

    str_values = [str(v) for v in values]

    if quote:
        str_values = ['"' + v + '"' for v in str_values]

    return ___.join(str_values)

print(build_csv_row('Alice', 92, 'A'))
print(build_csv_row('Bob', 78, 'C', delimiter='|', quote=True))

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# def build_csv_row(*values, **formatting):
#     delimiter = formatting.get('delimiter', ',')
#     quote     = formatting.get('quote', False)
#
#     str_values = [str(v) for v in values]
#
#     if quote:
#         str_values = ['"' + v + '"' for v in str_values]
#
#     return delimiter.join(str_values)
#
# print(build_csv_row('Alice', 92, 'A'))
# print(build_csv_row('Bob', 78, 'C', delimiter='|', quote=True))
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 3: Student Record System</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Write two functions that use *args and **kwargs to manage student records:
#
#   1. create_student(name, *courses)
#        Returns a dict with 'name' and 'courses' (list of enrolled courses)
#
#   2. update_student(student, **updates)
#        Merges new key-value pairs into the student dict and returns it
#
# Demonstrate:
#   - Creating a student named 'Alice' enrolled in 'Python', 'Data Science'
#   - Updating her record with gpa=3.8 and year='sophomore'
#   - Printing the final record</pre>
# </div>

# %%
def create_student(name, *courses):
    # Return a dict with 'name' and 'courses'
    return {
        'name': ___,
        'courses': list(___),
    }

def update_student(student, **updates):
    # Merge updates into student dict and return it
    student.update(___)
    return student

alice = create_student('Alice', 'Python', 'Data Science')
alice = update_student(alice, gpa=3.8, year='sophomore')
print(alice)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# def create_student(name, *courses):
#     return {
#         'name': name,
#         'courses': list(courses),
#     }
#
# def update_student(student, **updates):
#     student.update(updates)
#     return student
#
# alice = create_student('Alice', 'Python', 'Data Science')
# alice = update_student(alice, gpa=3.8, year='sophomore')
# print(alice)
# ```
#
# </details>
