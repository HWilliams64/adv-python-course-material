# %% [markdown]
# # The @property Decorator, Getters and Setters

# %% [markdown]
# ## @property Decorator in Python
#
# The `@property` decorator is a built-in decorator in Python for the property() function. It is used to define methods in a class that behave like attributes. This allows for the encapsulation of data, providing a way of adding getters, setters, and deleters in object-oriented programming.

# %% [markdown]
# ### Defining Getters with @property
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/jJJUESyt1k4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# A getter method allows you to access the value of a property without directly exposing the property's implementation.

# %%
class Student:
    def __init__(self, name, age):
        self._name = name
        self._age = age

    @property
    def name(self):
        return self._name

    @property
    def age(self):
        return self._age


student = Student('Tony', 18)

print(student.name)  # Rather than student.name()

print(student.age)  # Rather than student.age()

# %% [markdown]
# - **`_name` and `_age`**: These are private attributes, indicated by the underscore prefix.
# - **`@property`**: By decorating the `name` and `age` methods with `@property`, they can be accessed like attributes (e.g., `student.name`).
#
# **💡 Notice:** Since `name` and `age` are properties they cannot be directly
# assigned new values like this:
#
# ```py
# ❌ student.name = 'John'
# ```
#
# We must use setter properties to assign new values.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: @property Getter</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a Rectangle class with _width and _height (protected attributes).
# Add @property getters for both so they can be read like plain attributes
# (e.g. r.width instead of r.get_width()).</pre>
# </div>

# %%
class Rectangle:
    def __init__(self, width, height):
        self._width = width
        self._height = height

    @property
    def width(self):
        return ___

    @property
    def height(self):
        return ___

r = Rectangle(5, 3)
print(r.width)    # 5  (no parentheses needed)
print(r.height)   # 3

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# class Rectangle:
#     def __init__(self, width, height):
#         self._width = width
#         self._height = height
#
#     @property
#     def width(self):
#         return self._width
#
#     @property
#     def height(self):
#         return self._height
#
# r = Rectangle(5, 3)
# print(r.width)    # 5
# print(r.height)   # 3
# ```
#
# </details>

# %% [markdown]
# ### Defining Setters with @property
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/Py2TVEQFbEY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# Setters allow you to set the value of a property. To define a setter, you use the `@property_name.setter` decorator.

# %%
class Student:
    def __init__(self, name, age):
        self._name = name
        self._age = age

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, value):
        if not value:
            raise ValueError("Name cannot be empty")
        self._name = value

    @property
    def age(self):
        return self._age

    @age.setter
    def age(self, value):
        if value < 0:
            raise ValueError("Age cannot be negative")
        self._age = value

# %% [markdown]
# - **`@name.setter` and `@age.setter`**: These decorators define setter methods for `name` and `age`, allowing validation before setting their values.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: @property Setter with Validation</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Add @width.setter and @height.setter to the Rectangle class.
# Each setter should raise a ValueError if the new value is not positive (> 0).
# Test with a valid change and one that raises an error.</pre>
# </div>

# %%
class Rectangle:
    def __init__(self, width, height):
        self._width = width
        self._height = height

    @property
    def width(self):
        return self._width

    @width.setter
    def width(self, value):
        if value <= 0:
            raise ValueError('Width must be positive')
        self.___ = value

    @property
    def height(self):
        return self._height

    @height.setter
    def height(self, value):
        if ___:
            raise ValueError('Height must be positive')
        self._height = ___

r = Rectangle(5, 3)
r.width = 10
print(r.width)   # 10

try:
    r.height = -1
except ValueError as e:
    print(e)     # Height must be positive

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# class Rectangle:
#     def __init__(self, width, height):
#         self._width = width
#         self._height = height
#
#     @property
#     def width(self):
#         return self._width
#
#     @width.setter
#     def width(self, value):
#         if value <= 0:
#             raise ValueError('Width must be positive')
#         self._width = value
#
#     @property
#     def height(self):
#         return self._height
#
#     @height.setter
#     def height(self, value):
#         if value <= 0:
#             raise ValueError('Height must be positive')
#         self._height = value
#
# r = Rectangle(5, 3)
# r.width = 10
# print(r.width)   # 10
#
# try:
#     r.height = -1
# except ValueError as e:
#     print(e)     # Height must be positive
# ```
#
# </details>

# %% [markdown]
# ## @cached_property Decorator
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/uSHaJ6iFjcU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# The `@cached_property` decorator is used to cache the result of a method that needs to perform an expensive computational task. The result is cached, and subsequent accesses to this property return the cached result instead of recalculating it.

# %% [markdown]
# ### Example of Using @cached_property

# %%
from functools import cached_property

class Circle:
    def __init__(self, radius):
        self.radius = radius

    @cached_property
    def area(self):
        print("Calculating area...")
        return 3.14159 * self.radius ** 2

circle = Circle(10)
print(circle.area)
print(circle.area)
print(circle.area)

other_circle = Circle(5)
print(other_circle.area)
print(other_circle.area)
# Out:
# Calculating area...
# 314.159
# 314.159
# 314.159
# Calculating area...
# 78.53975
# 78.53975

# %% [markdown]
# - **`@cached_property`**: Caches the `area` calculation, so it's computed only once.
# - **Accessing `circle.area`**: The first time it calculates and caches the area. Subsequent accesses return the cached value without recalculating.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: @cached_property</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Add @cached_property for area and perimeter to the Rectangle class.
# Each should print 'Computing...' on first access to confirm caching.
# Notice that subsequent accesses skip the computation.</pre>
# </div>

# %%
from functools import cached_property

class Rectangle:
    def __init__(self, width, height):
        self._width = width
        self._height = height

    @property
    def width(self): return self._width

    @property
    def height(self): return self._height

    @cached_property
    def area(self):
        print('Computing area...')
        return ___

    @cached_property
    def perimeter(self):
        print('Computing perimeter...')
        return ___

r = Rectangle(4, 6)
print(r.area)       # Computing area... then 24
print(r.area)       # 24 (cached — no print)
print(r.perimeter)  # Computing perimeter... then 20

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# from functools import cached_property
#
# class Rectangle:
#     def __init__(self, width, height):
#         self._width = width
#         self._height = height
#
#     @property
#     def width(self): return self._width
#
#     @property
#     def height(self): return self._height
#
#     @cached_property
#     def area(self):
#         print('Computing area...')
#         return self._width * self._height
#
#     @cached_property
#     def perimeter(self):
#         print('Computing perimeter...')
#         return 2 * (self._width + self._height)
#
# r = Rectangle(4, 6)
# print(r.area)       # Computing area... \n 24
# print(r.area)       # 24  (cached)
# print(r.perimeter)  # Computing perimeter... \n 20
# ```
#
# </details>

# %% [markdown]
# ---
# ## Practice Problems

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 1: Temperature Converter</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a Temperature class using @property and @cached_property.
# Requirements:
#   - __init__(self, celsius): stores as _celsius (protected)
#   - @property celsius getter: returns _celsius
#   - @celsius.setter: raises ValueError if value is below -273.15 (absolute zero)
#   - @property fahrenheit: computed from celsius each time (not cached)
#       formula: (celsius * 9/5) + 32
#   - @cached_property kelvin: computed once (celsius + 273.15)
#
# Create a Temperature, read all three scales, update celsius, then
# notice that fahrenheit updates but kelvin stays cached.</pre>
# </div>

# %%
from functools import cached_property

class Temperature:
    def __init__(self, celsius):
        self._celsius = celsius

    @property
    def celsius(self):
        pass

    @celsius.setter
    def celsius(self, value):
        pass

    @property
    def fahrenheit(self):
        pass

    @cached_property
    def kelvin(self):
        pass

t = Temperature(100)
print(t.celsius)     # 100
print(t.fahrenheit)  # 212.0
print(t.kelvin)      # 373.15 (cached)
t.celsius = 0
print(t.fahrenheit)  # 32.0   (updates — not cached)
print(t.kelvin)      # 373.15 (still cached!)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# from functools import cached_property
#
# class Temperature:
#     def __init__(self, celsius):
#         self._celsius = celsius
#
#     @property
#     def celsius(self):
#         return self._celsius
#
#     @celsius.setter
#     def celsius(self, value):
#         if value < -273.15:
#             raise ValueError('Temperature cannot go below absolute zero (-273.15 C)')
#         self._celsius = value
#
#     @property
#     def fahrenheit(self):
#         return (self._celsius * 9 / 5) + 32
#
#     @cached_property
#     def kelvin(self):
#         return self._celsius + 273.15
#
# t = Temperature(100)
# print(t.celsius)     # 100
# print(t.fahrenheit)  # 212.0
# print(t.kelvin)      # 373.15
# t.celsius = 0
# print(t.fahrenheit)  # 32.0   (updated)
# print(t.kelvin)      # 373.15 (still cached from initial value)
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 2: Student GPA Tracker</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a Student class that uses @property and @cached_property.
# Requirements:
#   - __init__(self, name): stores _name (protected); grades = [] (list of scores)
#   - @property name getter and @name.setter: setter validates name is not empty
#   - add_grade(score): validates score is 0-100, appends to grades
#   - @cached_property gpa: computes the average of all grades (compute once)
#   - describe(): prints name and gpa
#
# Create a student, add 3 grades, print GPA. Then add another grade and observe
# that GPA remains cached (this is a trade-off of @cached_property).</pre>
# </div>

# %%
from functools import cached_property

class Student:
    def __init__(self, name):
        self._name = name
        self.grades = []

    @property
    def name(self):
        pass

    @name.setter
    def name(self, value):
        pass

    def add_grade(self, score):
        pass

    @cached_property
    def gpa(self):
        pass

    def describe(self):
        pass

s = Student('Alice')
s.add_grade(90)
s.add_grade(85)
s.add_grade(92)
s.describe()           # Alice | GPA: 89.0
s.add_grade(100)       # won't change cached GPA
print(s.gpa)           # still 89.0

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# from functools import cached_property
#
# class Student:
#     def __init__(self, name):
#         self._name = name
#         self.grades = []
#
#     @property
#     def name(self):
#         return self._name
#
#     @name.setter
#     def name(self, value):
#         if not value:
#             raise ValueError('Name cannot be empty')
#         self._name = value
#
#     def add_grade(self, score):
#         if not (0 <= score <= 100):
#             raise ValueError('Score must be between 0 and 100')
#         self.grades.append(score)
#
#     @cached_property
#     def gpa(self):
#         if not self.grades:
#             return 0
#         return sum(self.grades) / len(self.grades)
#
#     def describe(self):
#         print(f'{self.name} | GPA: {self.gpa:.1f}')
#
# s = Student('Alice')
# s.add_grade(90)
# s.add_grade(85)
# s.add_grade(92)
# s.describe()           # Alice | GPA: 89.0
# s.add_grade(100)       # won't change cached GPA
# print(s.gpa)           # still 89.0
# ```
#
# </details>
