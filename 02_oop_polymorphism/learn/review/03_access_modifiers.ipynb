# %% [markdown]
# # Understanding Access Modifiers in Python
#
# <style>
# html,body        {height: 100%;}
# .wrapper         {width: 80%; max-width: 1280px; height: 100%; margin: 0 auto; background: rgba(255, 255, 255, .0); padding-bottom: 50px}
# .h_iframe        {position: relative; padding-top: 56%;}
# .h_iframe iframe {position: absolute; top: 0; left: 0; width: 100%; height: 100%;}
# </style>
#
# <div class="wrapper">
#     <div class="h_iframe">
#         <iframe height="2" width="2" src="https://www.youtube.com/embed/n8tL3nAlXH8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#     </div>
# </div>
#
# Access modifiers, also known as access specifiers, are foundational elements in object-oriented programming languages. Their primary role is to establish rules for how classes, methods, and variables can be accessed within a program. To put it simply, they help define the boundaries or the 'scope' of a particular piece of data or function. For instance, a class or a method may be accessible from anywhere in the code, or it may be limited to its own class or even a particular method within that class.
#
# Access modifiers are integral in safeguarding data integrity and encapsulation in your programs. They prevent unauthorized access and modification of data, ensuring that only approved parts of your code can interact with the data or methods that these modifiers protect.
#
# But when it comes to Python, things are a bit different. Python doesn't offer the traditional access modifiers like 'private', 'public', or 'protected' found in languages such as Java or C++. However, Python provides certain conventions, primarily using underscores, to simulate the behavior of access modifiers, albeit in a more flexible and less enforced manner. In the following tutorial, we'll explore how these conventions work.
#
# Let's go over the main ones:

# %% [markdown]
# ## 1. No Underscore
#
# If a variable, method, or class has no leading underscore, it's considered public. This means it can be accessed from within its class, its subclass, and anywhere else. This is the default for most methods and variables in a class.
#
# Example:

# %%
class MyClass:
    def __init__(self):
        self.public_var = "I'm public!"

my_instance = MyClass()
print(my_instance.public_var)  # I'm public!

# %% [markdown]
# In this case, `public_var` is accessible from anywhere — inside the class, outside the class, in subclasses, and so on.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Public Attributes</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a Car class with public attributes make and model,
# and a public describe() method. Access the attribute and call the
# method directly from outside the class.</pre>
# </div>

# %%
class Car:
    def __init__(self, make, model):
        self.make = ___    # public attribute
        self.model = ___   # public attribute

    def describe(self):    # public method
        print(f'This is a {self.___} {self.___}')

c = Car('Toyota', 'Camry')
print(c.___)   # access make directly
c.___()        # call describe directly

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# class Car:
#     def __init__(self, make, model):
#         self.make = make
#         self.model = model
#
#     def describe(self):
#         print(f'This is a {self.make} {self.model}')
#
# c = Car('Toyota', 'Camry')
# print(c.make)  # Toyota
# c.describe()   # This is a Toyota Camry
# ```
#
# </details>

# %% [markdown]
# ## 2. Single Underscore (`_`)
#
# A leading single underscore (like `_var`) is a Python convention that indicates a name is meant for internal use. It's considered a "weak" internal use or private variable, method, or class — i.e., it should not be accessed directly. But it's mostly only a convention, and Python doesn't stop you from accessing it directly.
#
# Example:

# %%
class MyClass:
    def __init__(self):
        self._internal_var = "I'm internal!"

my_instance = MyClass()
print(my_instance._internal_var)  # I'm internal!

# %% [markdown]
# Though we can access `_internal_var` just like `public_var`, by convention we wouldn't do so outside of its class.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Protected Attributes (Single Underscore)</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Refactor the Car class to use _make and _model (protected by convention).
# Add a describe() method that accesses them through self.
# Note: Python doesn't enforce the protection — you can still access them
# from outside, but by convention you shouldn't.</pre>
# </div>

# %%
class Car:
    def __init__(self, make, model):
        self._make = ___    # protected (by convention)
        self._model = ___

    def describe(self):
        print(f'This is a {self.___} {self.___}')

c = Car('Toyota', 'Camry')
c.describe()         # works fine through the method
print(c.___)         # still accessible, but not recommended

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# class Car:
#     def __init__(self, make, model):
#         self._make = make
#         self._model = model
#
#     def describe(self):
#         print(f'This is a {self._make} {self._model}')
#
# c = Car('Toyota', 'Camry')
# c.describe()          # This is a Toyota Camry
# print(c._make)        # Toyota — still accessible, but not recommended
# ```
#
# </details>

# %% [markdown]
# ## 3. Double Underscore (`__`)
#
# A double underscore prefix (like `__var`) causes the Python interpreter to rewrite the attribute name in order to avoid naming conflicts in subclasses. This is also known as name mangling. The interpreter changes the name of the variable in a way that makes it harder to create collisions when the class is extended later.
#
# Example:

# %% [markdown]
# ```python
# class MyClass:
#     def __init__(self):
#         self.__private_var = "I'm private!"
#
# my_instance = MyClass()
# print(my_instance.__private_var)  # Raises an AttributeError
# ```

# %% [markdown]
# If you try to access `__private_var` directly, you'll get an error. However, the variable is still accessible using its mangled name:

# %%
print(my_instance._MyClass__private_var)  # I'm private!

# %% [markdown]
# The double underscore is a strong suggestion to "stay away" — it's meant for things that need to avoid naming conflicts with names defined by subclasses.
#
# Remember that Python's philosophy is "we're all consenting adults here," meaning you shouldn't put arbitrary restrictions on accessing parts of a class. These conventions are in place to help avoid errors, not to enforce a strict level of variable access like in Java or C++.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Private Attributes (Double Underscore)</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a SecureVault class with a private __pin attribute.
#   1. Add a check_pin(attempt) method that returns True if attempt matches __pin.
#   2. Try accessing __pin directly — it should raise AttributeError.
#   3. Show that name mangling allows access via _SecureVault__pin.</pre>
# </div>

# %%
class SecureVault:
    def __init__(self, pin):
        self.__pin = ___   # private attribute (name mangled)

    def check_pin(self, attempt):
        return self.___ == attempt

vault = SecureVault(1234)
print(vault.check_pin(1234))   # True

try:
    print(vault.__pin)         # Should raise AttributeError
except AttributeError as e:
    print(f'Error: {e}')

# Access via mangled name (possible, but not recommended)
print(vault.___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# class SecureVault:
#     def __init__(self, pin):
#         self.__pin = pin
#
#     def check_pin(self, attempt):
#         return self.__pin == attempt
#
# vault = SecureVault(1234)
# print(vault.check_pin(1234))         # True
#
# try:
#     print(vault.__pin)
# except AttributeError as e:
#     print(f'Error: {e}')
#
# print(vault._SecureVault__pin)       # 1234 — mangled name
# ```
#
# </details>

# %% [markdown]
# ---
# ## Practice Problems

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 1: Bank Account</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a BankAccount class that demonstrates all three access modifier conventions.
# Requirements:
#   - Public:    owner (name of the account holder)
#   - Protected: _transaction_history (list of transaction strings)
#   - Private:   __balance (the actual balance, never exposed directly)
#   - deposit(amount): adds to balance; appends 'Deposit: +X' to history
#   - withdraw(amount): subtracts from balance; raises ValueError if insufficient funds;
#     appends 'Withdrawal: -X' to history
#   - get_balance(): returns __balance (controlled access)
#   - show_history(): prints all transactions
#
# Create an account, deposit and withdraw, then show the history.</pre>
# </div>

# %%
class BankAccount:
    def __init__(self, owner, initial_balance):
        self.owner = owner               # public
        self._transaction_history = []   # protected
        self.__balance = initial_balance # private

    def deposit(self, amount): pass
    def withdraw(self, amount): pass
    def get_balance(self): pass
    def show_history(self): pass

acct = BankAccount('Alice', 500)
acct.deposit(200)
acct.withdraw(100)
print(acct.get_balance())  # 600
acct.show_history()

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# class BankAccount:
#     def __init__(self, owner, initial_balance):
#         self.owner = owner
#         self._transaction_history = []
#         self.__balance = initial_balance
#
#     def deposit(self, amount):
#         self.__balance += amount
#         self._transaction_history.append(f'Deposit: +{amount}')
#
#     def withdraw(self, amount):
#         if amount > self.__balance:
#             raise ValueError('Insufficient funds')
#         self.__balance -= amount
#         self._transaction_history.append(f'Withdrawal: -{amount}')
#
#     def get_balance(self):
#         return self.__balance
#
#     def show_history(self):
#         print(f'{self.owner} Transaction History:')
#         for t in self._transaction_history:
#             print(f'  {t}')
#
# acct = BankAccount('Alice', 500)
# acct.deposit(200)
# acct.withdraw(100)
# print(acct.get_balance())  # 600
# acct.show_history()
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 2: User Profile</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Create a UserProfile class that uses access modifiers to protect sensitive data.
# Requirements:
#   - Public:    username
#   - Protected: _email (should only be updated through a method)
#   - Private:   __password (stored; never returned directly)
#   - update_email(new_email): validates the email contains '@', then updates _email
#   - change_password(old_pw, new_pw): only updates if old_pw matches __password
#   - verify_password(attempt): returns True if attempt matches __password
#   - describe(): prints username and email (NOT the password)
#
# Create a profile, update the email, change the password, and verify it.</pre>
# </div>

# %%
class UserProfile:
    def __init__(self, username, email, password):
        self.username = username      # public
        self._email = email           # protected
        self.__password = password    # private

    def update_email(self, new_email): pass
    def change_password(self, old_pw, new_pw): pass
    def verify_password(self, attempt): pass
    def describe(self): pass

u = UserProfile('alice99', 'alice@old.com', 'secret')
u.update_email('alice@new.com')
u.change_password('secret', 'newsecret')
print(u.verify_password('newsecret'))  # True
print(u.verify_password('secret'))     # False
u.describe()

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# class UserProfile:
#     def __init__(self, username, email, password):
#         self.username = username
#         self._email = email
#         self.__password = password
#
#     def update_email(self, new_email):
#         if '@' not in new_email:
#             raise ValueError('Invalid email address')
#         self._email = new_email
#
#     def change_password(self, old_pw, new_pw):
#         if old_pw != self.__password:
#             raise ValueError('Incorrect current password')
#         self.__password = new_pw
#
#     def verify_password(self, attempt):
#         return self.__password == attempt
#
#     def describe(self):
#         print(f'User: {self.username} | Email: {self._email}')
#
# u = UserProfile('alice99', 'alice@old.com', 'secret')
# u.update_email('alice@new.com')
# u.change_password('secret', 'newsecret')
# print(u.verify_password('newsecret'))  # True
# print(u.verify_password('secret'))     # False
# u.describe()
# ```
#
# </details>
