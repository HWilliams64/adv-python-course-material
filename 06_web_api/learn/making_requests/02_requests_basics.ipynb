# %% [markdown]
# # Making HTTP Requests with Python's Requests Library
#
# Python's `requests` library is a package used for making HTTP requests. It abstracts the complexities of making requests behind a beautiful, simple API, allowing you to send HTTP requests with just a few lines of code. Here's a simple tutorial on how to use it.

# %% [markdown]
# ## Installation
#
# If you not working in a GT Workspace/IDE you must install the `requests`
# library, you can do so using pip, the Python package installer. Run the command
# below in your computer termianl (If you are working in the GT IDE you can skip
# this step):
#
#
# ```sh
# pip install requests
# ```

# %% [markdown]
# ## Making a GET Request
#
# Now that you have `requests` installed, let's start with a basic GET request. Let's fetch a webpage, for example, `http://example.com`.

# %%
import requests

response = requests.get('http://graderthan.com')

print(response.text)

# %% [markdown]
# In the above script, `requests.get()` is a method that sends a GET request to the specified URL. It returns a `Response` object, which contains the server's response to the request. We then print out the response text using `response.text`.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Fetch a Public API Endpoint</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Use requests.get() to fetch the Star Wars API root at 'https://swapi.dev/api/'.
# Print the status code and the first 200 characters of the response text.
#
# Note: Results depend on your network connection.</pre>
# </div>

# %%
import requests

response = requests.get('https://swapi.dev/api/')

print('Status code:', ___)
print('Response preview:', response.text[:___])

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import requests
#
# response = requests.get('https://swapi.dev/api/')
#
# print('Status code:', response.status_code)
# print('Response preview:', response.text[:200])
# ```
#
# </details>

# %% [markdown]
# ## Handling Response Status
#
# You can also check the status of your request by examining the `status_code` property of the response:

# %%
print(response.status_code)

# %% [markdown]
# A `200` status code means your request was successful, while a `404` status code indicates that the resource you were looking for was not found.
#
# ## Adding Query Parameters
#
# If you want to add query parameters to your GET request, you can do so by adding them to the URL or by using the `params` parameter of the `get` method.
#
# ```python
# payload = {'key1': 'value1', 'key2': 'value2'}
# response = requests.get('http://httpbin.org/get', params=payload)
#
# print(response.url)
# print(response.text)
# ```
#
# ## Making a POST Request
#
# To send a POST request, you can use the `requests.post()` method:
#
# ```python
# payload = {'key1': 'value1', 'key2': 'value2'}
# response = requests.post('http://httpbin.org/post', data=payload)
#
# print(response.text)
# ```
#
# ## Handling JSON Response
#
# Many HTTP APIs will return data in JSON format. The `requests` library provides a built-in JSON decoder:
#
# ```python
# response = requests.get('http://httpbin.org/get')
# data = response.json()
#
# print(data)
# ```
#
# The `response.json()` method will parse the JSON response into a Python dictionary.
#
# This is just the beginning of what you can do with the `requests` library. It also supports other HTTP methods like PUT, DELETE, HEAD, and OPTIONS, and features like custom headers, file uploads, timeouts, handling cookies, and more. Be sure to check out the [official documentation](http://docs.python-requests.org/) for more information.

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Try It Out: Handle Status Codes with Branching</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Make a GET request to 'https://swapi.dev/api/people/1/' (Luke Skywalker).
# If the status code is 200, print 'Success! Data received.'
# Otherwise, print 'Failed with status: <code>'.</pre>
# </div>

# %%
import requests

response = requests.get('https://swapi.dev/api/people/1/')

if response.___ == 200:
    print('Success! Data received.')
else:
    print('Failed with status:', ___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import requests
#
# response = requests.get('https://swapi.dev/api/people/1/')
#
# if response.status_code == 200:
#     print('Success! Data received.')
# else:
#     print('Failed with status:', response.status_code)
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 1: Fetch and Display a Star Wars Character</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Make a GET request to 'https://swapi.dev/api/people/1/' (Luke Skywalker).
# If successful (status_code == 200):
#   - Parse the JSON response using response.json()
#   - Print the character's name, height, mass, and birth_year
# Otherwise, print an error message with the status code.</pre>
# </div>

# %%
import requests

response = requests.get('https://swapi.dev/api/people/1/')

if response.___ == 200:
    data = response.___()  # parse JSON
    print('Name:      ', data[___])
    print('Height:    ', data[___])
    print('Mass:      ', data[___])
    print('Birth year:', data[___])
else:
    print('Error:', response.status_code)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import requests
#
# response = requests.get('https://swapi.dev/api/people/1/')
#
# if response.status_code == 200:
#     data = response.json()
#     print('Name:      ', data['name'])
#     print('Height:    ', data['height'])
#     print('Mass:      ', data['mass'])
#     print('Birth year:', data['birth_year'])
# else:
#     print('Error:', response.status_code)
# ```
#
# </details>

# %% [markdown]
# <div style="background: var(--vscode-textBlockQuote-background, var(--jp-layout-color2, rgba(74,144,217,0.08))); border-left: 4px solid var(--vscode-textLink-foreground, var(--jp-brand-color1, #4a90d9)); color: var(--vscode-foreground, inherit); padding: 12px 16px; border-radius: 0 4px 4px 0; margin: 12px 0; max-width: 100%; box-sizing: border-box;">
# <strong>Practice Problem 2: Check a List of API Endpoints</strong>
# <pre style="background:transparent; white-space:pre-wrap; overflow-x:auto; margin:8px 0 0 0;">Given the list of paths below, make a GET request to each one
# (prepend 'https://swapi.dev/api/' to each path) and print
# whether the request returned 200 (OK) or a different status code (ERROR).
#
# paths = ['people/1/', 'planets/1/', 'films/1/', 'notreal/999/']</pre>
# </div>

# %%
import requests

base_url = 'https://swapi.dev/api/'
paths = ['people/1/', 'planets/1/', 'films/1/', 'notreal/999/']

for path in paths:
    url = ___ + path
    response = requests.get(url)
    if response.___ == 200:
        print(path, '-> OK')
    else:
        print(path, '-> ERROR', response.___)

# %% [markdown]
# <details>
# <summary><strong>Show Answer</strong></summary>
#
# ```python
# import requests
#
# base_url = 'https://swapi.dev/api/'
# paths = ['people/1/', 'planets/1/', 'films/1/', 'notreal/999/']
#
# for path in paths:
#     url = base_url + path
#     response = requests.get(url)
#     if response.status_code == 200:
#         print(path, '-> OK')
#     else:
#         print(path, '-> ERROR', response.status_code)
# ```
#
# </details>
